# %%
# import

import numpy as np
import pandas as pd
import random

# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping
from keras.optimizers import *

# general
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_error
from math import sqrt

import datetime

# %%
now = datetime.datetime.now
np.random.seed(1337)  # for reproducibility

# %%
timesteps = 240  # number of timesteps
nr = 90   # number of repetitions
n_dim = 117  # dimension of the data sequences

# %%
import DataViconLoad   # Import the data
Correct_data, Correct_label, Incorrect_data, Incorrect_label = DataViconLoad.load_data()

# Print the size of the data 
print(Correct_data.shape, 'correct sequences')
print(Correct_label.shape, 'correct labels')
print(Incorrect_data.shape, 'incorrect sequences')
print(Incorrect_label.shape, 'incorrect labels')
# Out:
# (90, 240, 117) correct sequences
# (90, 1) correct labels
# (90, 240, 117) incorrect sequences
# (90, 1) incorrect labels

# %%
# Split the data into training and validation sets
# Training set: 60%
# Testing set: 20%
# Validation set: 20%

# Sample random indices
trainidx1 = random.sample(range(0,Correct_data.shape[0]),int(nr*0.6))
trainidx2 = random.sample(range(0,Incorrect_data.shape[0]),int(nr*0.6))

tempidx1 = np.setdiff1d(np.arange(0,nr,1),trainidx1)
tempidx2 = np.setdiff1d(np.arange(0,nr,1),trainidx2)

valididx1 = tempidx1[::2] 
valididx2 = tempidx1[1::2]

testidx1 = tempidx2[1::2]
testidx2 = tempidx2[::2]


# Training set: data and labels
train_x = np.concatenate((Correct_data[trainidx1,:,:],Incorrect_data[trainidx2,:,:]))
print(train_x.shape, 'training data')
train_y = np.concatenate((np.squeeze(Correct_label[trainidx1]),np.squeeze(Incorrect_label[trainidx2])))
print(train_y.shape, 'training labels')


# Testing set: data and labels
test_x = np.concatenate((Correct_data[testidx1,:,:],Incorrect_data[testidx2,:,:]))
print(test_x.shape, 'testing data')
test_y = np.concatenate((np.squeeze(Correct_label[testidx1]),np.squeeze(Incorrect_label[testidx2])))
print(test_y.shape, 'testing labels')

# Validation set: data and labels
valid_x = np.concatenate((Correct_data[valididx1,:,:],Incorrect_data[valididx2,:,:]))
print(valid_x.shape, 'validation data')
valid_y = np.concatenate((np.squeeze(Correct_label[valididx1]),np.squeeze(Incorrect_label[valididx2])))
print(valid_y.shape, 'validation labels')
# Out:
# (108, 240, 117) training data
# (108,) training labels
# (36, 240, 117) testing data
# (36,) testing labels
# (36, 240, 117) validation data
# (36,) validation labels

# %%
# Reduce the data length by a factor of 2, 4, and 8 
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
train_x_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_2 = np.zeros(train_x_2.shape)
test_x_2 = np.zeros(train_x_2.shape)

train_x_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_4 = np.zeros(train_x_4.shape)
test_x_4 = np.zeros(train_x_4.shape)

train_x_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_8 = np.zeros(train_x_8.shape)
test_x_8 = np.zeros(train_x_8.shape)

train_x_2 = train_x[:,::,:]
valid_x_2 = valid_x[:,::,:]
test_x_2 = test_x[:,::,:]

train_x_4 = train_x[:,::,:]
valid_x_4 = valid_x[:,::,:]
test_x_4 = test_x[:,::,:]

train_x_8 = train_x[:,::,:]
valid_x_8 = valid_x[:,::,:]
test_x_8 = test_x[:,::,:]

# %%
# Code to re-order the 117 dimensional skeleton data from the Vicon optical tracker into trunk, left arm, right arm, left leg and right leg
def reorder_data(x):
    X_trunk = np.zeros((x.shape[0],x.shape[1],12))
    X_left_arm = np.zeros((x.shape[0],x.shape[1],18))
    X_right_arm = np.zeros((x.shape[0],x.shape[1],18))
    X_left_leg = np.zeros((x.shape[0],x.shape[1],21))
    X_right_leg = np.zeros((x.shape[0],x.shape[1],21))
    X_trunk =  np.concatenate((x[:,:,15:18], x[:,:,18:21], x[:,:,24:27], x[:,:,27:30]), axis = 2)
    X_left_arm = np.concatenate((x[:,:,81:84], x[:,:,87:90], x[:,:,93:96], x[:,:,99:102], x[:,:,105:108], x[:,:,111:114]), axis = 2)
    X_right_arm = np.concatenate((x[:,:,84:87], x[:,:,90:93], x[:,:,96:99], x[:,:,102:105], x[:,:,108:111], x[:,:,114:117]), axis = 2)  
    X_left_leg = np.concatenate((x[:,:,33:36], x[:,:,39:42], x[:,:,45:48], x[:,:,51:54], x[:,:,57:60], x[:,:,63:66], x[:,:,69:72]), axis = 2)
    X_right_leg = np.concatenate((x[:,:,36:39], x[:,:,42:45], x[:,:,48:51], x[:,:,54:57], x[:,:,60:63], x[:,:,66:69], x[:,:,72:75]), axis = 2)
    x_segmented = np.concatenate((X_trunk, X_right_arm, X_left_arm, X_right_leg, X_left_leg),axis = -1)
    return x_segmented

# %%
# Reorder the data dimensions to correspond to the five body parts
trainx =  reorder_data(train_x)
validx =  reorder_data(valid_x)
testx =  reorder_data(test_x)

trainx_2 =  reorder_data(train_x_2)
validx_2 =  reorder_data(valid_x_2)
testx_2 =  reorder_data(test_x_2)

trainx_4 =  reorder_data(train_x_4)
validx_4 =  reorder_data(valid_x_4)
testx_4 =  reorder_data(test_x_4)

trainx_8 =  reorder_data(train_x_8)
validx_8 =  reorder_data(valid_x_8)
testx_8 =  reorder_data(test_x_8)

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)
    
    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.007,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)
   
    print('shape of tcn_layer: ', tcn_layer.shape)
    
    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim1, n_dim2, ndim3):
    
    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim1)
    
    tcn_2 = createTCNLayers(input_2, timesteps, n_dim2)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)    
    print('tcn-2: ', tcn_2.shape)
    
    tcn_3 = createTCNLayers(input_4, timesteps, n_dim2)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)    
    print('tcn-3: ', tcn_3.shape)
        
    tcn_5 = createTCNLayers(input_8, timesteps, n_dim3)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)    
    print('tcn-5: ', tcn_5.shape)
    
    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=-1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')
    
    return final_tcn

# %%
n_dim = 90 # dimension after segmenting the data into body parts
n_dim1 = 12 # trunk dimension
n_dim2 = 18 # arms dimension
n_dim3 = 21 # legs dimension

# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps, n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:12])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 12:30])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 30:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:69])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 69:90])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:12])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 12:30])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 30:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:69])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 69:90])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:12])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 12:30])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 30:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:69])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 69:90])(seq_input_4)


#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:12])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 12:30])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 30:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:69])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 69:90])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1, n_dim2, n_dim3)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim1, n_dim2, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'sigmoid')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 12)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 12)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 12)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 12)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  full_scale (InputLayer)        [(None, 240, 90)]    0           []
#
#  half_scale (InputLayer)        [(None, 240, 90)]    0           []
#
#  quarter_scale (InputLayer)     [(None, 240, 90)]    0           []
#
#  eighth_scale (InputLayer)      [(None, 240, 90)]    0           []
#
#  lambda (Lambda)                (None, 240, 12)      0           ['full_scale[0][0]']
#
#  lambda_5 (Lambda)              (None, 240, 12)      0           ['half_scale[0][0]']
#
#  lambda_10 (Lambda)             (None, 240, 12)      0           ['quarter_scale[0][0]']
#
#  lambda_15 (Lambda)             (None, 240, 12)      0           ['eighth_scale[0][0]']
#
#  lambda_1 (Lambda)              (None, 240, 18)      0           ['full_scale[0][0]']
#
#  lambda_6 (Lambda)              (None, 240, 18)      0           ['half_scale[0][0]']
#
#  lambda_11 (Lambda)             (None, 240, 18)      0           ['quarter_scale[0][0]']
#
#  lambda_16 (Lambda)             (None, 240, 18)      0           ['eighth_scale[0][0]']
#
#  lambda_2 (Lambda)              (None, 240, 18)      0           ['full_scale[0][0]']
#
#  lambda_7 (Lambda)              (None, 240, 18)      0           ['half_scale[0][0]']
#
#  lambda_12 (Lambda)             (None, 240, 18)      0           ['quarter_scale[0][0]']
#
#  lambda_17 (Lambda)             (None, 240, 18)      0           ['eighth_scale[0][0]']
#
#  lambda_3 (Lambda)              (None, 240, 21)      0           ['full_scale[0][0]']
#
#  lambda_8 (Lambda)              (None, 240, 21)      0           ['half_scale[0][0]']
#
#  lambda_13 (Lambda)             (None, 240, 21)      0           ['quarter_scale[0][0]']
#
#  lambda_18 (Lambda)             (None, 240, 21)      0           ['eighth_scale[0][0]']
#
#  lambda_4 (Lambda)              (None, 240, 21)      0           ['full_scale[0][0]']
#
#  lambda_9 (Lambda)              (None, 240, 21)      0           ['half_scale[0][0]']
#
#  lambda_14 (Lambda)             (None, 240, 21)      0           ['quarter_scale[0][0]']
#
#  lambda_19 (Lambda)             (None, 240, 21)      0           ['eighth_scale[0][0]']
#
#  tcn (TCN)                      (None, 240, 12)      5328        ['lambda[0][0]']
#
#  tcn_1 (TCN)                    (None, 240, 12)      5328        ['lambda_5[0][0]']
#
#  tcn_2 (TCN)                    (None, 240, 12)      5328        ['lambda_10[0][0]']
#
#  tcn_3 (TCN)                    (None, 240, 12)      5328        ['lambda_15[0][0]']
#
#  tcn_4 (TCN)                    (None, 240, 12)      5772        ['lambda_1[0][0]']
#
#  tcn_5 (TCN)                    (None, 240, 12)      5772        ['lambda_6[0][0]']
#
#  tcn_6 (TCN)                    (None, 240, 12)      5772        ['lambda_11[0][0]']
#
#  tcn_7 (TCN)                    (None, 240, 12)      5772        ['lambda_16[0][0]']
#
#  tcn_8 (TCN)                    (None, 240, 12)      5772        ['lambda_2[0][0]']
#
#  tcn_9 (TCN)                    (None, 240, 12)      5772        ['lambda_7[0][0]']
#
#  tcn_10 (TCN)                   (None, 240, 12)      5772        ['lambda_12[0][0]']
#
#  tcn_11 (TCN)                   (None, 240, 12)      5772        ['lambda_17[0][0]']
#
#  tcn_12 (TCN)                   (None, 240, 12)      5916        ['lambda_3[0][0]']
#
#  tcn_13 (TCN)                   (None, 240, 12)      5916        ['lambda_8[0][0]']
#
#  tcn_14 (TCN)                   (None, 240, 12)      5916        ['lambda_13[0][0]']
#
#  tcn_15 (TCN)                   (None, 240, 12)      5916        ['lambda_18[0][0]']
#
#  tcn_16 (TCN)                   (None, 240, 12)      5916        ['lambda_4[0][0]']
#
#  tcn_17 (TCN)                   (None, 240, 12)      5916        ['lambda_9[0][0]']
#
#  tcn_18 (TCN)                   (None, 240, 12)      5916        ['lambda_14[0][0]']
#
#  tcn_19 (TCN)                   (None, 240, 12)      5916        ['lambda_19[0][0]']
#
#  concatenate (Concatenate)      (None, 240, 48)      0           ['tcn[0][0]',
#                                                                   'tcn_1[0][0]',
#                                                                   'tcn_2[0][0]',
#                                                                   'tcn_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 240, 48)      0           ['tcn_4[0][0]',
#                                                                   'tcn_5[0][0]',
#                                                                   'tcn_6[0][0]',
#                                                                   'tcn_7[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 240, 48)      0           ['tcn_8[0][0]',
#                                                                   'tcn_9[0][0]',
#                                                                   'tcn_10[0][0]',
#                                                                   'tcn_11[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 240, 48)      0           ['tcn_12[0][0]',
#                                                                   'tcn_13[0][0]',
#                                                                   'tcn_14[0][0]',
#                                                                   'tcn_15[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 240, 48)      0           ['tcn_16[0][0]',
#                                                                   'tcn_17[0][0]',
#                                                                   'tcn_18[0][0]',
#                                                                   'tcn_19[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 240, 240)     0           ['concatenate[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  tcn_20 (TCN)                   (None, 240, 12)      14652       ['concatenate_5[0][0]']
#
#  tcn_21 (TCN)                   (None, 240, 8)       1176        ['tcn_20[0][0]']
#
#  tcn_22 (TCN)                   (None, 6)            546         ['tcn_21[0][0]']
#
#  dense (Dense)                  (None, 1)            7           ['tcn_22[0][0]']
#
# ==================================================================================================
# Total params: 131,197
# Trainable params: 131,101
# Non-trainable params: 96
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.003), loss='mse')

# %%
t = now()
    
early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=150, verbose=1, 
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = [early_stopping])

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/150
# 16/16 [==============================] - 68s 893ms/step - loss: 0.0058 - val_loss: 0.0086
# Epoch 2/150
# 16/16 [==============================] - 7s 409ms/step - loss: 0.0039 - val_loss: 0.0086
# Epoch 3/150
# 16/16 [==============================] - 7s 428ms/step - loss: 0.0019 - val_loss: 0.0086
# Epoch 4/150
# 16/16 [==============================] - 7s 415ms/step - loss: 0.0019 - val_loss: 0.0079
# Epoch 5/150
# 16/16 [==============================] - 7s 419ms/step - loss: 9.6052e-04 - val_loss: 0.0058
# Epoch 6/150
# 16/16 [==============================] - 7s 418ms/step - loss: 0.0015 - val_loss: 0.0082
# Epoch 7/150
# 16/16 [==============================] - 7s 409ms/step - loss: 9.0680e-04 - val_loss: 0.0219
# Epoch 8/150
# 16/16 [==============================] - 7s 422ms/step - loss: 0.0010 - val_loss: 0.0297
# Epoch 9/150
# 16/16 [==============================] - 6s 397ms/step - loss: 9.4107e-04 - val_loss: 0.0170
# Epoch 10/150
# 16/16 [==============================] - 6s 407ms/step - loss: 0.0011 - val_loss: 0.0053
# Epoch 11/150
# 16/16 [==============================] - 6s 404ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 12/150
# 16/16 [==============================] - 6s 399ms/step - loss: 9.2829e-04 - val_loss: 0.0026
# Epoch 13/150
# 16/16 [==============================] - 7s 418ms/step - loss: 8.8719e-04 - val_loss: 0.0027
# Epoch 14/150
# 16/16 [==============================] - 6s 401ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 15/150
# 16/16 [==============================] - 7s 415ms/step - loss: 7.2137e-04 - val_loss: 0.0014
# Epoch 16/150
# 16/16 [==============================] - 6s 404ms/step - loss: 6.4953e-04 - val_loss: 4.7368e-04
# Epoch 17/150
# 16/16 [==============================] - 6s 407ms/step - loss: 9.8035e-04 - val_loss: 0.0013
# Epoch 18/150
# 16/16 [==============================] - 7s 412ms/step - loss: 6.1458e-04 - val_loss: 0.0028
# Epoch 19/150
# 16/16 [==============================] - 7s 417ms/step - loss: 7.2680e-04 - val_loss: 0.0011
# Epoch 20/150
# 16/16 [==============================] - 7s 417ms/step - loss: 6.5659e-04 - val_loss: 1.7869e-04
# Epoch 21/150
# 16/16 [==============================] - 6s 406ms/step - loss: 4.9495e-04 - val_loss: 2.7689e-04
# Epoch 22/150
# 16/16 [==============================] - 6s 401ms/step - loss: 6.3427e-04 - val_loss: 2.3151e-04
# Epoch 23/150
# 16/16 [==============================] - 7s 409ms/step - loss: 5.9226e-04 - val_loss: 1.3589e-04
# Epoch 24/150
# 16/16 [==============================] - 6s 400ms/step - loss: 6.4885e-04 - val_loss: 2.5862e-04
# Epoch 25/150
# 16/16 [==============================] - 7s 415ms/step - loss: 5.6930e-04 - val_loss: 3.3359e-04
# Epoch 26/150
# 16/16 [==============================] - 6s 400ms/step - loss: 3.1081e-04 - val_loss: 2.6166e-04
# Epoch 27/150
# 16/16 [==============================] - 7s 416ms/step - loss: 4.4360e-04 - val_loss: 2.1802e-04
# Epoch 28/150
# 16/16 [==============================] - 7s 421ms/step - loss: 4.9672e-04 - val_loss: 2.0687e-04
# Epoch 29/150
# 16/16 [==============================] - 6s 408ms/step - loss: 3.1143e-04 - val_loss: 1.2161e-04
# Epoch 30/150
# 16/16 [==============================] - 7s 421ms/step - loss: 4.6577e-04 - val_loss: 5.2321e-04
# Epoch 31/150
# 16/16 [==============================] - 7s 409ms/step - loss: 5.6372e-04 - val_loss: 1.8989e-04
# Epoch 32/150
# 16/16 [==============================] - 7s 422ms/step - loss: 3.0307e-04 - val_loss: 1.6260e-04
# Epoch 33/150
# 16/16 [==============================] - 6s 406ms/step - loss: 3.0889e-04 - val_loss: 2.7103e-04
# Epoch 34/150
# 16/16 [==============================] - 7s 411ms/step - loss: 2.6967e-04 - val_loss: 1.7693e-04
# Epoch 35/150
# 16/16 [==============================] - 7s 417ms/step - loss: 2.6166e-04 - val_loss: 2.0527e-04
# Epoch 36/150
# 16/16 [==============================] - 6s 407ms/step - loss: 3.9642e-04 - val_loss: 2.2837e-04
# Epoch 37/150
# 16/16 [==============================] - 7s 421ms/step - loss: 3.5404e-04 - val_loss: 3.3603e-04
# Epoch 38/150
# 16/16 [==============================] - 7s 422ms/step - loss: 2.6118e-04 - val_loss: 2.0783e-04
# Epoch 39/150
# 16/16 [==============================] - 7s 419ms/step - loss: 3.2530e-04 - val_loss: 2.1951e-04
# Epoch 40/150
# 16/16 [==============================] - 7s 412ms/step - loss: 1.6008e-04 - val_loss: 4.6694e-04
# Epoch 41/150
# 16/16 [==============================] - 6s 407ms/step - loss: 2.4000e-04 - val_loss: 8.9371e-05
# Epoch 42/150
# 16/16 [==============================] - 7s 433ms/step - loss: 2.8432e-04 - val_loss: 2.3519e-04
# Epoch 43/150
# 16/16 [==============================] - 6s 407ms/step - loss: 3.1210e-04 - val_loss: 1.8019e-04
# Epoch 44/150
# 16/16 [==============================] - 7s 422ms/step - loss: 2.9267e-04 - val_loss: 1.5119e-04
# Epoch 45/150
# 16/16 [==============================] - 7s 412ms/step - loss: 4.0694e-04 - val_loss: 8.9038e-05
# Epoch 46/150
# 16/16 [==============================] - 7s 408ms/step - loss: 2.8469e-04 - val_loss: 2.1592e-04
# Epoch 47/150
# 16/16 [==============================] - 7s 423ms/step - loss: 3.2709e-04 - val_loss: 1.7167e-04
# Epoch 48/150
# 16/16 [==============================] - 5s 337ms/step - loss: 1.9999e-04 - val_loss: 4.2304e-04
# Epoch 49/150
# 16/16 [==============================] - 7s 429ms/step - loss: 3.1480e-04 - val_loss: 4.0874e-04
# Epoch 50/150
# 16/16 [==============================] - 7s 424ms/step - loss: 3.0679e-04 - val_loss: 1.5538e-04
# Epoch 51/150
# 16/16 [==============================] - 7s 417ms/step - loss: 2.9229e-04 - val_loss: 1.0801e-04
# Epoch 52/150
# 16/16 [==============================] - 7s 421ms/step - loss: 4.7258e-04 - val_loss: 3.7829e-04
# Epoch 53/150
# 16/16 [==============================] - 7s 408ms/step - loss: 3.7587e-04 - val_loss: 2.7699e-04
# Epoch 54/150
# 16/16 [==============================] - 7s 425ms/step - loss: 1.8079e-04 - val_loss: 1.1629e-04
# Epoch 55/150
# 16/16 [==============================] - 7s 412ms/step - loss: 1.6980e-04 - val_loss: 7.7553e-05
# Epoch 56/150
# 16/16 [==============================] - 7s 417ms/step - loss: 1.9111e-04 - val_loss: 9.1615e-05
# Epoch 57/150
# 16/16 [==============================] - 7s 419ms/step - loss: 1.7757e-04 - val_loss: 5.8478e-05
# Epoch 58/150
# 16/16 [==============================] - 7s 409ms/step - loss: 1.6977e-04 - val_loss: 1.4575e-04
# Epoch 59/150
# 16/16 [==============================] - 7s 424ms/step - loss: 1.6019e-04 - val_loss: 1.3218e-04
# Epoch 60/150
# 16/16 [==============================] - 7s 412ms/step - loss: 1.6256e-04 - val_loss: 1.0748e-04
# Epoch 61/150
# 16/16 [==============================] - 7s 421ms/step - loss: 1.8825e-04 - val_loss: 7.6764e-05
# Epoch 62/150
# 16/16 [==============================] - 7s 439ms/step - loss: 1.9039e-04 - val_loss: 6.6531e-05
# Epoch 63/150
# 16/16 [==============================] - 7s 421ms/step - loss: 2.7462e-04 - val_loss: 2.4135e-04
# Epoch 64/150
# 16/16 [==============================] - 7s 426ms/step - loss: 1.7486e-04 - val_loss: 1.2483e-04
# Epoch 65/150
# 16/16 [==============================] - 7s 428ms/step - loss: 1.9769e-04 - val_loss: 1.7227e-04
# Epoch 66/150
# 16/16 [==============================] - 7s 443ms/step - loss: 1.5805e-04 - val_loss: 4.6598e-05
# Epoch 67/150
# 16/16 [==============================] - 7s 428ms/step - loss: 1.4782e-04 - val_loss: 8.0017e-05
# Epoch 68/150
# 16/16 [==============================] - 7s 443ms/step - loss: 1.6828e-04 - val_loss: 6.2958e-05
# Epoch 69/150
# 16/16 [==============================] - 7s 426ms/step - loss: 2.0141e-04 - val_loss: 7.2170e-05
# Epoch 70/150
# 16/16 [==============================] - 7s 430ms/step - loss: 1.4174e-04 - val_loss: 5.6681e-05
# Epoch 71/150
# 16/16 [==============================] - 7s 432ms/step - loss: 1.9891e-04 - val_loss: 1.0172e-04
# Epoch 72/150
# 16/16 [==============================] - 7s 429ms/step - loss: 2.2252e-04 - val_loss: 1.1331e-04
# Epoch 73/150
# 16/16 [==============================] - 7s 455ms/step - loss: 1.6830e-04 - val_loss: 8.5007e-05
# Epoch 74/150
# 16/16 [==============================] - 7s 431ms/step - loss: 1.6308e-04 - val_loss: 1.2224e-04
# Epoch 75/150
# 16/16 [==============================] - 7s 437ms/step - loss: 2.3750e-04 - val_loss: 1.3807e-04
# Epoch 76/150
# 16/16 [==============================] - 7s 438ms/step - loss: 1.5550e-04 - val_loss: 1.0568e-04
# Epoch 77/150
# 16/16 [==============================] - 7s 431ms/step - loss: 1.5961e-04 - val_loss: 1.5857e-04
# Epoch 78/150
# 16/16 [==============================] - 7s 431ms/step - loss: 2.3637e-04 - val_loss: 9.4492e-05
# Epoch 79/150
# 16/16 [==============================] - 7s 424ms/step - loss: 2.5812e-04 - val_loss: 2.0547e-04
# Epoch 80/150
# 16/16 [==============================] - 7s 434ms/step - loss: 1.6772e-04 - val_loss: 4.0699e-04
# Epoch 81/150
# 16/16 [==============================] - 7s 420ms/step - loss: 2.6683e-04 - val_loss: 2.7959e-04
# Epoch 82/150
# 16/16 [==============================] - 7s 438ms/step - loss: 1.6394e-04 - val_loss: 7.0299e-05
# Epoch 83/150
# 16/16 [==============================] - 7s 431ms/step - loss: 1.7752e-04 - val_loss: 9.8472e-05
# Epoch 84/150
# 16/16 [==============================] - 7s 437ms/step - loss: 1.6171e-04 - val_loss: 1.7058e-04
# Epoch 85/150
# 16/16 [==============================] - 7s 431ms/step - loss: 2.4639e-04 - val_loss: 1.5789e-04
# Epoch 86/150
# 16/16 [==============================] - 7s 424ms/step - loss: 2.1318e-04 - val_loss: 2.2117e-04
# Epoch 87/150
# 16/16 [==============================] - 7s 435ms/step - loss: 3.2048e-04 - val_loss: 1.4884e-04
# Epoch 88/150
# 16/16 [==============================] - 7s 425ms/step - loss: 1.2666e-04 - val_loss: 7.5434e-05
# Epoch 89/150
# 16/16 [==============================] - 7s 451ms/step - loss: 1.7292e-04 - val_loss: 6.5680e-05
# Epoch 90/150
# 16/16 [==============================] - 7s 427ms/step - loss: 1.2605e-04 - val_loss: 8.5539e-05
# Epoch 91/150
# 16/16 [==============================] - 7s 453ms/step - loss: 1.4195e-04 - val_loss: 7.7175e-05
# Epoch 92/150
# 16/16 [==============================] - 7s 435ms/step - loss: 1.2915e-04 - val_loss: 5.0948e-05
# Epoch 93/150
# 16/16 [==============================] - 7s 423ms/step - loss: 1.2938e-04 - val_loss: 6.8269e-05
# Epoch 94/150
# 16/16 [==============================] - 7s 437ms/step - loss: 1.1774e-04 - val_loss: 7.1885e-05
# Epoch 95/150
# 16/16 [==============================] - 7s 425ms/step - loss: 1.1271e-04 - val_loss: 7.7606e-05
# Epoch 96/150
# 16/16 [==============================] - 7s 445ms/step - loss: 1.6522e-04 - val_loss: 1.0932e-04
# Epoch 97/150
# 16/16 [==============================] - 7s 429ms/step - loss: 1.8152e-04 - val_loss: 1.3380e-04
# Epoch 98/150
# 16/16 [==============================] - 7s 446ms/step - loss: 1.9047e-04 - val_loss: 5.7522e-05
# Epoch 99/150
# 16/16 [==============================] - 7s 426ms/step - loss: 1.7983e-04 - val_loss: 3.6682e-05
# Epoch 100/150
# 16/16 [==============================] - 7s 431ms/step - loss: 7.5282e-05 - val_loss: 5.1763e-05
# Epoch 101/150
# 16/16 [==============================] - 7s 445ms/step - loss: 1.4924e-04 - val_loss: 9.4646e-05
# Epoch 102/150
# 16/16 [==============================] - 7s 425ms/step - loss: 1.1805e-04 - val_loss: 3.6517e-05
# Epoch 103/150
# 16/16 [==============================] - 7s 444ms/step - loss: 9.2067e-05 - val_loss: 4.0019e-05
# Epoch 104/150
# 16/16 [==============================] - 7s 430ms/step - loss: 1.0562e-04 - val_loss: 4.5825e-05
# Epoch 105/150
# 16/16 [==============================] - 7s 443ms/step - loss: 1.0067e-04 - val_loss: 7.5455e-05
# Epoch 106/150
# 16/16 [==============================] - 7s 416ms/step - loss: 8.3468e-05 - val_loss: 8.3412e-05
# Epoch 107/150
# 16/16 [==============================] - 7s 423ms/step - loss: 1.0361e-04 - val_loss: 3.8442e-05
# Epoch 108/150
# 16/16 [==============================] - 7s 427ms/step - loss: 1.0994e-04 - val_loss: 5.3867e-05
# Epoch 109/150
# 16/16 [==============================] - 7s 429ms/step - loss: 1.3015e-04 - val_loss: 4.2980e-05
# Epoch 110/150
# 16/16 [==============================] - 7s 434ms/step - loss: 6.9576e-05 - val_loss: 5.1968e-05
# Epoch 111/150
# 16/16 [==============================] - 7s 416ms/step - loss: 1.1213e-04 - val_loss: 3.9617e-05
# Epoch 112/150
# 16/16 [==============================] - 7s 431ms/step - loss: 1.0164e-04 - val_loss: 5.7146e-05
# Epoch 113/150
# 16/16 [==============================] - 7s 418ms/step - loss: 1.2551e-04 - val_loss: 7.9210e-05
# Epoch 114/150
# 16/16 [==============================] - 7s 420ms/step - loss: 6.0462e-05 - val_loss: 4.4277e-05
# Epoch 115/150
# 16/16 [==============================] - 7s 418ms/step - loss: 8.0711e-05 - val_loss: 6.9054e-05
# Epoch 116/150
# 16/16 [==============================] - 7s 411ms/step - loss: 1.2115e-04 - val_loss: 4.4564e-05
# Epoch 117/150
# 16/16 [==============================] - 7s 434ms/step - loss: 8.4292e-05 - val_loss: 6.4676e-05
# Epoch 118/150
# 16/16 [==============================] - 7s 418ms/step - loss: 1.4384e-04 - val_loss: 3.6797e-05
# Epoch 119/150
# 16/16 [==============================] - 7s 424ms/step - loss: 1.4324e-04 - val_loss: 3.2400e-05
# Epoch 120/150
# 16/16 [==============================] - 7s 416ms/step - loss: 7.7642e-05 - val_loss: 6.9882e-05
# Epoch 121/150
# 16/16 [==============================] - 7s 423ms/step - loss: 9.0790e-05 - val_loss: 7.7163e-05
# Epoch 122/150
# 16/16 [==============================] - 7s 423ms/step - loss: 7.4368e-05 - val_loss: 6.0239e-05
# Epoch 123/150
# 16/16 [==============================] - 7s 410ms/step - loss: 8.4351e-05 - val_loss: 1.5096e-04
# Epoch 124/150
# 16/16 [==============================] - 7s 426ms/step - loss: 8.5210e-05 - val_loss: 1.8005e-04
# Epoch 125/150
# 16/16 [==============================] - 7s 410ms/step - loss: 9.9913e-05 - val_loss: 1.6275e-04
# Epoch 126/150
# 16/16 [==============================] - 7s 413ms/step - loss: 3.1014e-04 - val_loss: 0.0018
# Epoch 127/150
# 16/16 [==============================] - 7s 417ms/step - loss: 4.9201e-04 - val_loss: 0.0013
# Epoch 128/150
# 16/16 [==============================] - 7s 408ms/step - loss: 3.5238e-04 - val_loss: 8.5105e-04
# Epoch 129/150
# 16/16 [==============================] - 7s 433ms/step - loss: 2.6200e-04 - val_loss: 9.3911e-05
# Epoch 130/150
# 16/16 [==============================] - 6s 407ms/step - loss: 2.6272e-04 - val_loss: 5.0714e-04
# Epoch 131/150
# 16/16 [==============================] - 7s 414ms/step - loss: 1.4625e-04 - val_loss: 2.7670e-04
# Epoch 132/150
# 16/16 [==============================] - 7s 408ms/step - loss: 1.6032e-04 - val_loss: 3.3433e-04
# Epoch 133/150
# 16/16 [==============================] - 6s 404ms/step - loss: 1.8575e-04 - val_loss: 9.2430e-05
# Epoch 134/150
# 16/16 [==============================] - 7s 420ms/step - loss: 1.2332e-04 - val_loss: 1.1315e-04
# Epoch 135/150
# 16/16 [==============================] - 7s 408ms/step - loss: 8.5539e-05 - val_loss: 1.0239e-04
# Epoch 136/150
# 16/16 [==============================] - 7s 421ms/step - loss: 9.7186e-05 - val_loss: 1.5089e-04
# Epoch 137/150
# 16/16 [==============================] - 7s 415ms/step - loss: 1.0713e-04 - val_loss: 8.5548e-05
# Epoch 138/150
# 16/16 [==============================] - 7s 423ms/step - loss: 6.1147e-05 - val_loss: 3.9218e-05
# Epoch 139/150
# 16/16 [==============================] - 7s 413ms/step - loss: 9.4769e-05 - val_loss: 5.6639e-05
# Epoch 140/150
# 16/16 [==============================] - 7s 408ms/step - loss: 9.9771e-05 - val_loss: 3.6684e-05
# Epoch 141/150
# 16/16 [==============================] - 7s 416ms/step - loss: 7.6533e-05 - val_loss: 6.6677e-05
# Epoch 142/150
# 16/16 [==============================] - 7s 410ms/step - loss: 4.9078e-05 - val_loss: 5.6090e-05
# Epoch 143/150
# 16/16 [==============================] - 7s 419ms/step - loss: 5.3076e-05 - val_loss: 4.0882e-05
# Epoch 144/150
# 16/16 [==============================] - 7s 416ms/step - loss: 6.3250e-05 - val_loss: 8.9523e-05
# Epoch 145/150
# 16/16 [==============================] - 7s 409ms/step - loss: 1.2161e-04 - val_loss: 4.8553e-05
# Epoch 146/150
# 16/16 [==============================] - 7s 432ms/step - loss: 6.1799e-05 - val_loss: 4.4585e-05
# Epoch 147/150
# 16/16 [==============================] - 7s 414ms/step - loss: 9.6100e-05 - val_loss: 3.7847e-05
# Epoch 148/150
# 16/16 [==============================] - 7s 429ms/step - loss: 7.2472e-05 - val_loss: 7.0489e-05
# Epoch 149/150
# 16/16 [==============================] - 7s 412ms/step - loss: 7.5318e-05 - val_loss: 2.6729e-05
# Epoch 150/150
# 16/16 [==============================] - 7s 417ms/step - loss: 9.3337e-05 - val_loss: 4.7470e-05
# Training time: 0:17:50.593611

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 4.90777165396139e-05
# Validation loss 2.6728570446721278e-05

# %%
# Plot the prediction of the model for the training and validation sets
pred_train = model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = model.predict([testx, testx_2, testx_4, testx_8])
# Out:
# 4/4 [==============================] - 9s 202ms/step
# 2/2 [==============================] - 0s 54ms/step

# %%
plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.1,1.1])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(test_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.1,1.1])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()
plt.savefig('TCN_LR003_E150.png', dpi=350)
plt.show()

# %%
# Calculate the cumulative deviation and rms deviation for the validation set
test_dev = abs(np.squeeze(pred_test)-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
rms_dev = sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
# Out:
# Mean absolute deviation: 0.00816937432977889
# RMS deviation: 0.012536127596397181
