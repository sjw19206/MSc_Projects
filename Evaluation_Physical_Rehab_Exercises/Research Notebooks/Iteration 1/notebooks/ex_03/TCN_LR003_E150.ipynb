# %%
# import

import numpy as np
import pandas as pd
import random

# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping
from keras.optimizers import *

# general
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_error
from math import sqrt

import datetime

# %%
now = datetime.datetime.now
np.random.seed(1337)  # for reproducibility

# %%
timesteps = 240  # number of timesteps
nr = 90   # number of repetitions
n_dim = 117  # dimension of the data sequences

# %%
import DataViconLoad   # Import the data
Correct_data, Correct_label, Incorrect_data, Incorrect_label = DataViconLoad.load_data()

# Print the size of the data 
print(Correct_data.shape, 'correct sequences')
print(Correct_label.shape, 'correct labels')
print(Incorrect_data.shape, 'incorrect sequences')
print(Incorrect_label.shape, 'incorrect labels')
# Out:
# (90, 240, 117) correct sequences
# (80, 1) correct labels
# (90, 240, 117) incorrect sequences
# (80, 1) incorrect labels

# %%
# Split the data into training and validation sets
# Training set: 60%
# Testing set: 20%
# Validation set: 20%

# Sample random indices
trainidx1 = random.sample(range(0,80),int(nr*0.6))
trainidx2 = random.sample(range(0,80),int(nr*0.6))

tempidx1 = np.setdiff1d(np.arange(0,80,1),trainidx1)
tempidx2 = np.setdiff1d(np.arange(0,80,1),trainidx2)

valididx1 = tempidx1[::2] 
valididx2 = tempidx1[1::2]

testidx1 = tempidx2[1::2]
testidx2 = tempidx2[::2]


# Training set: data and labels
train_x = np.concatenate((Correct_data[trainidx1,:,:],Incorrect_data[trainidx2,:,:]))
print(train_x.shape, 'training data')
train_y = np.concatenate((np.squeeze(Correct_label[trainidx1]),np.squeeze(Incorrect_label[trainidx2])))
print(train_y.shape, 'training labels')


# Testing set: data and labels
test_x = np.concatenate((Correct_data[testidx1,:,:],Incorrect_data[testidx2,:,:]))
print(test_x.shape, 'testing data')
test_y = np.concatenate((np.squeeze(Correct_label[testidx1]),np.squeeze(Incorrect_label[testidx2])))
print(test_y.shape, 'testing labels')

# Validation set: data and labels
valid_x = np.concatenate((Correct_data[valididx1,:,:],Incorrect_data[valididx2,:,:]))
print(valid_x.shape, 'validation data')
valid_y = np.concatenate((np.squeeze(Correct_label[valididx1]),np.squeeze(Incorrect_label[valididx2])))
print(valid_y.shape, 'validation labels')
# Out:
# (108, 240, 117) training data
# (108,) training labels
# (26, 240, 117) testing data
# (26,) testing labels
# (26, 240, 117) validation data
# (26,) validation labels

# %%
# Reduce the data length by a factor of 2, 4, and 8 
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
train_x_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_2 = np.zeros(train_x_2.shape)
test_x_2 = np.zeros(train_x_2.shape)

train_x_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_4 = np.zeros(train_x_4.shape)
test_x_4 = np.zeros(train_x_4.shape)

train_x_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_8 = np.zeros(train_x_8.shape)
test_x_8 = np.zeros(train_x_8.shape)

train_x_2 = train_x[:,::,:]
valid_x_2 = valid_x[:,::,:]
test_x_2 = test_x[:,::,:]

train_x_4 = train_x[:,::,:]
valid_x_4 = valid_x[:,::,:]
test_x_4 = test_x[:,::,:]

train_x_8 = train_x[:,::,:]
valid_x_8 = valid_x[:,::,:]
test_x_8 = test_x[:,::,:]

# %%
# Code to re-order the 117 dimensional skeleton data from the Vicon optical tracker into trunk, left arm, right arm, left leg and right leg
def reorder_data(x):
    X_trunk = np.zeros((x.shape[0],x.shape[1],12))
    X_left_arm = np.zeros((x.shape[0],x.shape[1],18))
    X_right_arm = np.zeros((x.shape[0],x.shape[1],18))
    X_left_leg = np.zeros((x.shape[0],x.shape[1],21))
    X_right_leg = np.zeros((x.shape[0],x.shape[1],21))
    X_trunk =  np.concatenate((x[:,:,15:18], x[:,:,18:21], x[:,:,24:27], x[:,:,27:30]), axis = 2)
    X_left_arm = np.concatenate((x[:,:,81:84], x[:,:,87:90], x[:,:,93:96], x[:,:,99:102], x[:,:,105:108], x[:,:,111:114]), axis = 2)
    X_right_arm = np.concatenate((x[:,:,84:87], x[:,:,90:93], x[:,:,96:99], x[:,:,102:105], x[:,:,108:111], x[:,:,114:117]), axis = 2)  
    X_left_leg = np.concatenate((x[:,:,33:36], x[:,:,39:42], x[:,:,45:48], x[:,:,51:54], x[:,:,57:60], x[:,:,63:66], x[:,:,69:72]), axis = 2)
    X_right_leg = np.concatenate((x[:,:,36:39], x[:,:,42:45], x[:,:,48:51], x[:,:,54:57], x[:,:,60:63], x[:,:,66:69], x[:,:,72:75]), axis = 2)
    x_segmented = np.concatenate((X_trunk, X_right_arm, X_left_arm, X_right_leg, X_left_leg),axis = -1)
    return x_segmented

# %%
# Reorder the data dimensions to correspond to the five body parts
trainx =  reorder_data(train_x)
validx =  reorder_data(valid_x)
testx =  reorder_data(test_x)

trainx_2 =  reorder_data(train_x_2)
validx_2 =  reorder_data(valid_x_2)
testx_2 =  reorder_data(test_x_2)

trainx_4 =  reorder_data(train_x_4)
validx_4 =  reorder_data(valid_x_4)
testx_4 =  reorder_data(test_x_4)

trainx_8 =  reorder_data(train_x_8)
validx_8 =  reorder_data(valid_x_8)
testx_8 =  reorder_data(test_x_8)

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)
    
    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.007,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)
   
    print('shape of tcn_layer: ', tcn_layer.shape)
    
    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim1, n_dim2, ndim3):
    
    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim1)
    
    tcn_2 = createTCNLayers(input_2, timesteps, n_dim2)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)    
    print('tcn-2: ', tcn_2.shape)
    
    tcn_3 = createTCNLayers(input_4, timesteps, n_dim2)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)    
    print('tcn-3: ', tcn_3.shape)
        
    tcn_5 = createTCNLayers(input_8, timesteps, n_dim3)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)    
    print('tcn-5: ', tcn_5.shape)
    
    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=-1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')
    
    return final_tcn

# %%
n_dim = 90 # dimension after segmenting the data into body parts
n_dim1 = 12 # trunk dimension
n_dim2 = 18 # arms dimension
n_dim3 = 21 # legs dimension

# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps, n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:12])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 12:30])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 30:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:69])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 69:90])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:12])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 12:30])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 30:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:69])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 69:90])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:12])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 12:30])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 30:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:69])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 69:90])(seq_input_4)


#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:12])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 12:30])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 30:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:69])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 69:90])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1, n_dim2, n_dim3)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim1, n_dim2, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'sigmoid')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 12)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 12)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 12)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 12)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 18)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-2:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-3:  (None, 240, 12)
# shape of input::  (None, 240, 21)
# shape of tcn_layer:  (None, 240, 12)
# tcn-5:  (None, 240, 12)
# final_tcn:  (None, 240, 48)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  full_scale (InputLayer)        [(None, 240, 90)]    0           []
#
#  half_scale (InputLayer)        [(None, 240, 90)]    0           []
#
#  quarter_scale (InputLayer)     [(None, 240, 90)]    0           []
#
#  eighth_scale (InputLayer)      [(None, 240, 90)]    0           []
#
#  lambda (Lambda)                (None, 240, 12)      0           ['full_scale[0][0]']
#
#  lambda_5 (Lambda)              (None, 240, 12)      0           ['half_scale[0][0]']
#
#  lambda_10 (Lambda)             (None, 240, 12)      0           ['quarter_scale[0][0]']
#
#  lambda_15 (Lambda)             (None, 240, 12)      0           ['eighth_scale[0][0]']
#
#  lambda_1 (Lambda)              (None, 240, 18)      0           ['full_scale[0][0]']
#
#  lambda_6 (Lambda)              (None, 240, 18)      0           ['half_scale[0][0]']
#
#  lambda_11 (Lambda)             (None, 240, 18)      0           ['quarter_scale[0][0]']
#
#  lambda_16 (Lambda)             (None, 240, 18)      0           ['eighth_scale[0][0]']
#
#  lambda_2 (Lambda)              (None, 240, 18)      0           ['full_scale[0][0]']
#
#  lambda_7 (Lambda)              (None, 240, 18)      0           ['half_scale[0][0]']
#
#  lambda_12 (Lambda)             (None, 240, 18)      0           ['quarter_scale[0][0]']
#
#  lambda_17 (Lambda)             (None, 240, 18)      0           ['eighth_scale[0][0]']
#
#  lambda_3 (Lambda)              (None, 240, 21)      0           ['full_scale[0][0]']
#
#  lambda_8 (Lambda)              (None, 240, 21)      0           ['half_scale[0][0]']
#
#  lambda_13 (Lambda)             (None, 240, 21)      0           ['quarter_scale[0][0]']
#
#  lambda_18 (Lambda)             (None, 240, 21)      0           ['eighth_scale[0][0]']
#
#  lambda_4 (Lambda)              (None, 240, 21)      0           ['full_scale[0][0]']
#
#  lambda_9 (Lambda)              (None, 240, 21)      0           ['half_scale[0][0]']
#
#  lambda_14 (Lambda)             (None, 240, 21)      0           ['quarter_scale[0][0]']
#
#  lambda_19 (Lambda)             (None, 240, 21)      0           ['eighth_scale[0][0]']
#
#  tcn (TCN)                      (None, 240, 12)      5328        ['lambda[0][0]']
#
#  tcn_1 (TCN)                    (None, 240, 12)      5328        ['lambda_5[0][0]']
#
#  tcn_2 (TCN)                    (None, 240, 12)      5328        ['lambda_10[0][0]']
#
#  tcn_3 (TCN)                    (None, 240, 12)      5328        ['lambda_15[0][0]']
#
#  tcn_4 (TCN)                    (None, 240, 12)      5772        ['lambda_1[0][0]']
#
#  tcn_5 (TCN)                    (None, 240, 12)      5772        ['lambda_6[0][0]']
#
#  tcn_6 (TCN)                    (None, 240, 12)      5772        ['lambda_11[0][0]']
#
#  tcn_7 (TCN)                    (None, 240, 12)      5772        ['lambda_16[0][0]']
#
#  tcn_8 (TCN)                    (None, 240, 12)      5772        ['lambda_2[0][0]']
#
#  tcn_9 (TCN)                    (None, 240, 12)      5772        ['lambda_7[0][0]']
#
#  tcn_10 (TCN)                   (None, 240, 12)      5772        ['lambda_12[0][0]']
#
#  tcn_11 (TCN)                   (None, 240, 12)      5772        ['lambda_17[0][0]']
#
#  tcn_12 (TCN)                   (None, 240, 12)      5916        ['lambda_3[0][0]']
#
#  tcn_13 (TCN)                   (None, 240, 12)      5916        ['lambda_8[0][0]']
#
#  tcn_14 (TCN)                   (None, 240, 12)      5916        ['lambda_13[0][0]']
#
#  tcn_15 (TCN)                   (None, 240, 12)      5916        ['lambda_18[0][0]']
#
#  tcn_16 (TCN)                   (None, 240, 12)      5916        ['lambda_4[0][0]']
#
#  tcn_17 (TCN)                   (None, 240, 12)      5916        ['lambda_9[0][0]']
#
#  tcn_18 (TCN)                   (None, 240, 12)      5916        ['lambda_14[0][0]']
#
#  tcn_19 (TCN)                   (None, 240, 12)      5916        ['lambda_19[0][0]']
#
#  concatenate (Concatenate)      (None, 240, 48)      0           ['tcn[0][0]',
#                                                                   'tcn_1[0][0]',
#                                                                   'tcn_2[0][0]',
#                                                                   'tcn_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 240, 48)      0           ['tcn_4[0][0]',
#                                                                   'tcn_5[0][0]',
#                                                                   'tcn_6[0][0]',
#                                                                   'tcn_7[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 240, 48)      0           ['tcn_8[0][0]',
#                                                                   'tcn_9[0][0]',
#                                                                   'tcn_10[0][0]',
#                                                                   'tcn_11[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 240, 48)      0           ['tcn_12[0][0]',
#                                                                   'tcn_13[0][0]',
#                                                                   'tcn_14[0][0]',
#                                                                   'tcn_15[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 240, 48)      0           ['tcn_16[0][0]',
#                                                                   'tcn_17[0][0]',
#                                                                   'tcn_18[0][0]',
#                                                                   'tcn_19[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 240, 240)     0           ['concatenate[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  tcn_20 (TCN)                   (None, 240, 12)      14652       ['concatenate_5[0][0]']
#
#  tcn_21 (TCN)                   (None, 240, 8)       1176        ['tcn_20[0][0]']
#
#  tcn_22 (TCN)                   (None, 6)            546         ['tcn_21[0][0]']
#
#  dense (Dense)                  (None, 1)            7           ['tcn_22[0][0]']
#
# ==================================================================================================
# Total params: 131,197
# Trainable params: 131,101
# Non-trainable params: 96
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.003), loss='mse')

# %%
t = now()
    
early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=150, verbose=1, 
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = [early_stopping])

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/150
# 16/16 [==============================] - 75s 1s/step - loss: 0.0827 - val_loss: 0.0065
# Epoch 2/150
# 16/16 [==============================] - 7s 437ms/step - loss: 0.0052 - val_loss: 0.0065
# Epoch 3/150
# 16/16 [==============================] - 7s 438ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 4/150
# 16/16 [==============================] - 7s 425ms/step - loss: 0.0047 - val_loss: 0.0062
# Epoch 5/150
# 16/16 [==============================] - 7s 441ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 6/150
# 16/16 [==============================] - 7s 416ms/step - loss: 0.0019 - val_loss: 0.0089
# Epoch 7/150
# 16/16 [==============================] - 7s 427ms/step - loss: 0.0019 - val_loss: 0.0167
# Epoch 8/150
# 16/16 [==============================] - 7s 424ms/step - loss: 0.0014 - val_loss: 0.0124
# Epoch 9/150
# 16/16 [==============================] - 7s 435ms/step - loss: 0.0017 - val_loss: 0.0076
# Epoch 10/150
# 16/16 [==============================] - 7s 432ms/step - loss: 0.0021 - val_loss: 0.0052
# Epoch 11/150
# 16/16 [==============================] - 7s 422ms/step - loss: 0.0018 - val_loss: 0.0061
# Epoch 12/150
# 16/16 [==============================] - 7s 437ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 13/150
# 16/16 [==============================] - 7s 424ms/step - loss: 0.0029 - val_loss: 0.0123
# Epoch 14/150
# 16/16 [==============================] - 7s 435ms/step - loss: 0.0010 - val_loss: 0.0093
# Epoch 15/150
# 16/16 [==============================] - 7s 422ms/step - loss: 9.4886e-04 - val_loss: 0.0079
# Epoch 16/150
# 16/16 [==============================] - 7s 430ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 17/150
# 16/16 [==============================] - 7s 434ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 18/150
# 16/16 [==============================] - 7s 427ms/step - loss: 0.0019 - val_loss: 0.0052
# Epoch 19/150
# 16/16 [==============================] - 7s 437ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 20/150
# 16/16 [==============================] - 7s 411ms/step - loss: 9.6900e-04 - val_loss: 0.0019
# Epoch 21/150
# 16/16 [==============================] - 7s 421ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 22/150
# 16/16 [==============================] - 7s 413ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 23/150
# 16/16 [==============================] - 7s 415ms/step - loss: 0.0013 - val_loss: 3.9665e-04
# Epoch 24/150
# 16/16 [==============================] - 7s 423ms/step - loss: 0.0012 - val_loss: 3.2960e-04
# Epoch 25/150
# 16/16 [==============================] - 7s 410ms/step - loss: 7.5936e-04 - val_loss: 5.2313e-04
# Epoch 26/150
# 16/16 [==============================] - 7s 430ms/step - loss: 0.0010 - val_loss: 4.2157e-04
# Epoch 27/150
# 16/16 [==============================] - 7s 412ms/step - loss: 7.1355e-04 - val_loss: 5.1240e-04
# Epoch 28/150
# 16/16 [==============================] - 7s 417ms/step - loss: 9.1735e-04 - val_loss: 3.8597e-04
# Epoch 29/150
# 16/16 [==============================] - 7s 430ms/step - loss: 0.0011 - val_loss: 5.0176e-04
# Epoch 30/150
# 16/16 [==============================] - 7s 444ms/step - loss: 0.0012 - val_loss: 3.3782e-04
# Epoch 31/150
# 16/16 [==============================] - 8s 475ms/step - loss: 8.1803e-04 - val_loss: 2.5384e-04
# Epoch 32/150
# 16/16 [==============================] - 7s 459ms/step - loss: 0.0013 - val_loss: 3.0950e-04
# Epoch 33/150
# 16/16 [==============================] - 7s 465ms/step - loss: 8.2786e-04 - val_loss: 0.0029
# Epoch 34/150
# 16/16 [==============================] - 7s 441ms/step - loss: 6.3454e-04 - val_loss: 3.4142e-04
# Epoch 35/150
# 16/16 [==============================] - 7s 451ms/step - loss: 5.2745e-04 - val_loss: 9.6727e-04
# Epoch 36/150
# 16/16 [==============================] - 7s 452ms/step - loss: 6.7891e-04 - val_loss: 4.9413e-04
# Epoch 37/150
# 16/16 [==============================] - 7s 462ms/step - loss: 9.4866e-04 - val_loss: 2.5733e-04
# Epoch 38/150
# 16/16 [==============================] - 7s 455ms/step - loss: 0.0013 - val_loss: 6.4544e-04
# Epoch 39/150
# 16/16 [==============================] - 7s 439ms/step - loss: 5.4604e-04 - val_loss: 0.0014
# Epoch 40/150
# 16/16 [==============================] - 7s 440ms/step - loss: 6.4302e-04 - val_loss: 9.3375e-04
# Epoch 41/150
# 16/16 [==============================] - 7s 433ms/step - loss: 7.6777e-04 - val_loss: 8.2216e-04
# Epoch 42/150
# 16/16 [==============================] - 7s 442ms/step - loss: 0.0011 - val_loss: 5.0826e-04
# Epoch 43/150
# 16/16 [==============================] - 7s 427ms/step - loss: 8.5855e-04 - val_loss: 3.7040e-04
# Epoch 44/150
# 16/16 [==============================] - 7s 471ms/step - loss: 8.0927e-04 - val_loss: 4.7748e-04
# Epoch 45/150
# 16/16 [==============================] - 7s 456ms/step - loss: 6.8664e-04 - val_loss: 4.5678e-04
# Epoch 46/150
# 16/16 [==============================] - 7s 463ms/step - loss: 6.9861e-04 - val_loss: 6.2585e-04
# Epoch 47/150
# 16/16 [==============================] - 7s 424ms/step - loss: 9.5895e-04 - val_loss: 4.4614e-04
# Epoch 48/150
# 16/16 [==============================] - 7s 422ms/step - loss: 7.5772e-04 - val_loss: 0.0014
# Epoch 49/150
# 16/16 [==============================] - 7s 431ms/step - loss: 6.9002e-04 - val_loss: 0.0040
# Epoch 50/150
# 16/16 [==============================] - 7s 446ms/step - loss: 0.0016 - val_loss: 0.0039
# Epoch 51/150
# 16/16 [==============================] - 7s 448ms/step - loss: 8.1833e-04 - val_loss: 0.0088
# Epoch 52/150
# 16/16 [==============================] - 7s 418ms/step - loss: 0.0010 - val_loss: 0.0035
# Epoch 53/150
# 16/16 [==============================] - 7s 431ms/step - loss: 8.5981e-04 - val_loss: 0.0020
# Epoch 54/150
# 16/16 [==============================] - 7s 453ms/step - loss: 8.8820e-04 - val_loss: 0.0016
# Epoch 55/150
# 16/16 [==============================] - 7s 437ms/step - loss: 7.5908e-04 - val_loss: 0.0011
# Epoch 56/150
# 16/16 [==============================] - 7s 457ms/step - loss: 6.9265e-04 - val_loss: 6.0837e-04
# Epoch 57/150
# 16/16 [==============================] - 8s 477ms/step - loss: 9.6055e-04 - val_loss: 4.8380e-04
# Epoch 58/150
# 16/16 [==============================] - 8s 498ms/step - loss: 7.6759e-04 - val_loss: 4.0875e-04
# Epoch 59/150
# 16/16 [==============================] - 7s 418ms/step - loss: 8.7887e-04 - val_loss: 5.1108e-04
# Epoch 60/150
# 16/16 [==============================] - 7s 437ms/step - loss: 6.2025e-04 - val_loss: 4.3818e-04
# Epoch 61/150
# 16/16 [==============================] - 7s 441ms/step - loss: 7.2306e-04 - val_loss: 4.0409e-04
# Epoch 62/150
# 16/16 [==============================] - 7s 434ms/step - loss: 5.4281e-04 - val_loss: 3.7346e-04
# Epoch 63/150
# 16/16 [==============================] - 7s 425ms/step - loss: 6.4275e-04 - val_loss: 3.0412e-04
# Epoch 64/150
# 16/16 [==============================] - 7s 434ms/step - loss: 4.4083e-04 - val_loss: 3.1208e-04
# Epoch 65/150
# 16/16 [==============================] - 8s 481ms/step - loss: 5.5912e-04 - val_loss: 5.8127e-04
# Epoch 66/150
# 16/16 [==============================] - 7s 433ms/step - loss: 6.5625e-04 - val_loss: 3.4146e-04
# Epoch 67/150
# 16/16 [==============================] - 7s 466ms/step - loss: 7.0872e-04 - val_loss: 2.7046e-04
# Epoch 68/150
# 16/16 [==============================] - 6s 397ms/step - loss: 5.6558e-04 - val_loss: 3.4916e-04
# Epoch 69/150
# 16/16 [==============================] - 7s 437ms/step - loss: 3.9697e-04 - val_loss: 6.9299e-04
# Epoch 70/150
# 16/16 [==============================] - 7s 427ms/step - loss: 6.1462e-04 - val_loss: 3.7535e-04
# Epoch 71/150
# 16/16 [==============================] - 7s 434ms/step - loss: 6.7295e-04 - val_loss: 3.8931e-04
# Epoch 72/150
# 16/16 [==============================] - 7s 425ms/step - loss: 5.4981e-04 - val_loss: 3.4967e-04
# Epoch 73/150
# 16/16 [==============================] - 7s 446ms/step - loss: 3.2566e-04 - val_loss: 2.7994e-04
# Epoch 74/150
# 16/16 [==============================] - 7s 451ms/step - loss: 3.1616e-04 - val_loss: 3.0950e-04
# Epoch 75/150
# 16/16 [==============================] - 7s 433ms/step - loss: 6.2216e-04 - val_loss: 3.2511e-04
# Epoch 76/150
# 16/16 [==============================] - 8s 501ms/step - loss: 3.6608e-04 - val_loss: 2.9084e-04
# Epoch 77/150
# 16/16 [==============================] - 7s 424ms/step - loss: 3.7481e-04 - val_loss: 2.9818e-04
# Epoch 78/150
# 16/16 [==============================] - 7s 431ms/step - loss: 5.6328e-04 - val_loss: 4.6337e-04
# Epoch 79/150
# 16/16 [==============================] - 7s 413ms/step - loss: 5.3281e-04 - val_loss: 3.3565e-04
# Epoch 80/150
# 16/16 [==============================] - 7s 439ms/step - loss: 5.2917e-04 - val_loss: 3.3589e-04
# Epoch 81/150
# 16/16 [==============================] - 8s 478ms/step - loss: 3.8690e-04 - val_loss: 4.8521e-04
# Epoch 82/150
# 16/16 [==============================] - 7s 452ms/step - loss: 4.8124e-04 - val_loss: 3.5658e-04
# Epoch 83/150
# 16/16 [==============================] - 8s 472ms/step - loss: 4.4863e-04 - val_loss: 2.2595e-04
# Epoch 84/150
# 16/16 [==============================] - 7s 433ms/step - loss: 6.0586e-04 - val_loss: 2.5099e-04
# Epoch 85/150
# 16/16 [==============================] - 8s 502ms/step - loss: 3.8127e-04 - val_loss: 2.6709e-04
# Epoch 86/150
# 16/16 [==============================] - 7s 465ms/step - loss: 4.2865e-04 - val_loss: 2.5897e-04
# Epoch 87/150
# 16/16 [==============================] - 7s 448ms/step - loss: 4.6798e-04 - val_loss: 2.5274e-04
# Epoch 88/150
# 16/16 [==============================] - 7s 424ms/step - loss: 6.7442e-04 - val_loss: 2.1348e-04
# Epoch 89/150
# 16/16 [==============================] - 7s 437ms/step - loss: 5.5432e-04 - val_loss: 3.4141e-04
# Epoch 90/150
# 16/16 [==============================] - 7s 424ms/step - loss: 4.8685e-04 - val_loss: 2.4882e-04
# Epoch 91/150
# 16/16 [==============================] - 7s 433ms/step - loss: 4.3959e-04 - val_loss: 2.3734e-04
# Epoch 92/150
# 16/16 [==============================] - 7s 434ms/step - loss: 3.9674e-04 - val_loss: 2.8355e-04
# Epoch 93/150
# 16/16 [==============================] - 7s 430ms/step - loss: 3.9499e-04 - val_loss: 3.3770e-04
# Epoch 94/150
# 16/16 [==============================] - 7s 450ms/step - loss: 3.5324e-04 - val_loss: 2.4337e-04
# Epoch 95/150
# 16/16 [==============================] - 7s 429ms/step - loss: 4.5329e-04 - val_loss: 3.6234e-04
# Epoch 96/150
# 16/16 [==============================] - 7s 443ms/step - loss: 3.3274e-04 - val_loss: 3.9159e-04
# Epoch 97/150
# 16/16 [==============================] - 7s 429ms/step - loss: 3.5499e-04 - val_loss: 2.1381e-04
# Epoch 98/150
# 16/16 [==============================] - 7s 438ms/step - loss: 3.9110e-04 - val_loss: 2.9048e-04
# Epoch 99/150
# 16/16 [==============================] - 7s 428ms/step - loss: 3.2746e-04 - val_loss: 3.8887e-04
# Epoch 100/150
# 16/16 [==============================] - 7s 430ms/step - loss: 5.1738e-04 - val_loss: 4.8849e-04
# Epoch 101/150
# 16/16 [==============================] - 7s 456ms/step - loss: 2.6722e-04 - val_loss: 4.9538e-04
# Epoch 102/150
# 16/16 [==============================] - 7s 421ms/step - loss: 4.0294e-04 - val_loss: 2.9836e-04
# Epoch 103/150
# 16/16 [==============================] - 7s 442ms/step - loss: 3.5768e-04 - val_loss: 2.8861e-04
# Epoch 104/150
# 16/16 [==============================] - 7s 429ms/step - loss: 3.1563e-04 - val_loss: 3.0412e-04
# Epoch 105/150
# 16/16 [==============================] - 7s 445ms/step - loss: 3.3877e-04 - val_loss: 3.2196e-04
# Epoch 106/150
# 16/16 [==============================] - 7s 432ms/step - loss: 3.3346e-04 - val_loss: 4.0490e-04
# Epoch 107/150
# 16/16 [==============================] - 7s 441ms/step - loss: 3.5718e-04 - val_loss: 3.6750e-04
# Epoch 108/150
# 16/16 [==============================] - 7s 437ms/step - loss: 3.5461e-04 - val_loss: 4.1549e-04
# Epoch 109/150
# 16/16 [==============================] - 7s 434ms/step - loss: 3.1658e-04 - val_loss: 2.5332e-04
# Epoch 110/150
# 16/16 [==============================] - 7s 451ms/step - loss: 4.9066e-04 - val_loss: 2.3649e-04
# Epoch 111/150
# 16/16 [==============================] - 7s 437ms/step - loss: 2.4063e-04 - val_loss: 2.0971e-04
# Epoch 112/150
# 16/16 [==============================] - 7s 445ms/step - loss: 2.1988e-04 - val_loss: 2.0696e-04
# Epoch 113/150
# 16/16 [==============================] - 7s 438ms/step - loss: 1.7238e-04 - val_loss: 1.8172e-04
# Epoch 114/150
# 16/16 [==============================] - 7s 443ms/step - loss: 2.1193e-04 - val_loss: 2.4891e-04
# Epoch 115/150
# 16/16 [==============================] - 7s 435ms/step - loss: 2.7969e-04 - val_loss: 2.8364e-04
# Epoch 116/150
# 16/16 [==============================] - 7s 424ms/step - loss: 2.8257e-04 - val_loss: 3.1044e-04
# Epoch 117/150
# 16/16 [==============================] - 7s 429ms/step - loss: 3.5579e-04 - val_loss: 2.2358e-04
# Epoch 118/150
# 16/16 [==============================] - 7s 423ms/step - loss: 3.6288e-04 - val_loss: 2.1127e-04
# Epoch 119/150
# 16/16 [==============================] - 7s 452ms/step - loss: 2.0800e-04 - val_loss: 2.3653e-04
# Epoch 120/150
# 16/16 [==============================] - 7s 451ms/step - loss: 2.6334e-04 - val_loss: 3.8054e-04
# Epoch 121/150
# 16/16 [==============================] - 8s 472ms/step - loss: 2.1370e-04 - val_loss: 3.4072e-04
# Epoch 122/150
# 16/16 [==============================] - 7s 433ms/step - loss: 1.2349e-04 - val_loss: 2.1879e-04
# Epoch 123/150
# 16/16 [==============================] - 7s 435ms/step - loss: 3.0362e-04 - val_loss: 3.1676e-04
# Epoch 124/150
# 16/16 [==============================] - 7s 426ms/step - loss: 2.7073e-04 - val_loss: 3.0319e-04
# Epoch 125/150
# 16/16 [==============================] - 7s 425ms/step - loss: 3.0528e-04 - val_loss: 6.2123e-04
# Epoch 126/150
# 16/16 [==============================] - 7s 444ms/step - loss: 3.2127e-04 - val_loss: 1.7504e-04
# Epoch 127/150
# 16/16 [==============================] - 7s 429ms/step - loss: 3.1694e-04 - val_loss: 2.6351e-04
# Epoch 128/150
# 16/16 [==============================] - 7s 449ms/step - loss: 2.6435e-04 - val_loss: 2.1027e-04
# Epoch 129/150
# 16/16 [==============================] - 7s 434ms/step - loss: 2.0088e-04 - val_loss: 1.9833e-04
# Epoch 130/150
# 16/16 [==============================] - 7s 438ms/step - loss: 1.9295e-04 - val_loss: 3.2393e-04
# Epoch 131/150
# 16/16 [==============================] - 7s 435ms/step - loss: 1.4479e-04 - val_loss: 2.4909e-04
# Epoch 132/150
# 16/16 [==============================] - 7s 435ms/step - loss: 1.6225e-04 - val_loss: 1.9045e-04
# Epoch 133/150
# 16/16 [==============================] - 7s 439ms/step - loss: 2.1415e-04 - val_loss: 3.6112e-04
# Epoch 134/150
# 16/16 [==============================] - 7s 427ms/step - loss: 1.6350e-04 - val_loss: 2.6344e-04
# Epoch 135/150
# 16/16 [==============================] - 7s 439ms/step - loss: 1.4405e-04 - val_loss: 1.7988e-04
# Epoch 136/150
# 16/16 [==============================] - 7s 427ms/step - loss: 2.7757e-04 - val_loss: 1.6971e-04
# Epoch 137/150
# 16/16 [==============================] - 7s 453ms/step - loss: 2.1651e-04 - val_loss: 1.5556e-04
# Epoch 138/150
# 16/16 [==============================] - 7s 433ms/step - loss: 1.9038e-04 - val_loss: 1.8648e-04
# Epoch 139/150
# 16/16 [==============================] - 7s 432ms/step - loss: 2.4134e-04 - val_loss: 1.7271e-04
# Epoch 140/150
# 16/16 [==============================] - 7s 441ms/step - loss: 1.4625e-04 - val_loss: 1.5134e-04
# Epoch 141/150
# 16/16 [==============================] - 7s 437ms/step - loss: 2.1483e-04 - val_loss: 1.3138e-04
# Epoch 142/150
# 16/16 [==============================] - 7s 438ms/step - loss: 2.4189e-04 - val_loss: 1.7468e-04
# Epoch 143/150
# 16/16 [==============================] - 7s 419ms/step - loss: 2.1687e-04 - val_loss: 3.6718e-04
# Epoch 144/150
# 16/16 [==============================] - 7s 444ms/step - loss: 3.1965e-04 - val_loss: 6.6964e-04
# Epoch 145/150
# 16/16 [==============================] - 7s 425ms/step - loss: 2.8406e-04 - val_loss: 3.5542e-04
# Epoch 146/150
# 16/16 [==============================] - 7s 436ms/step - loss: 2.0282e-04 - val_loss: 1.5958e-04
# Epoch 147/150
# 16/16 [==============================] - 7s 433ms/step - loss: 1.7242e-04 - val_loss: 2.1387e-04
# Epoch 148/150
# 16/16 [==============================] - 7s 430ms/step - loss: 1.5817e-04 - val_loss: 1.6344e-04
# Epoch 149/150
# 16/16 [==============================] - 6s 353ms/step - loss: 2.2844e-04 - val_loss: 1.6277e-04
# Epoch 150/150
# 16/16 [==============================] - 7s 419ms/step - loss: 1.4681e-04 - val_loss: 1.8069e-04
# Training time: 0:18:38.745543

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.0001234873925568536
# Validation loss 0.00013137632049620152

# %%
# Plot the prediction of the model for the training and validation sets
pred_train = model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = model.predict([testx, testx_2, testx_4, testx_8])
# Out:
# 4/4 [==============================] - 10s 221ms/step
# 1/1 [==============================] - 0s 226ms/step

# %%
plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.1,1.1])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(test_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.1,1.1])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()
plt.savefig('TCN_LR003_E150.png', dpi=350)
plt.show()

# %%
# Calculate the cumulative deviation and rms deviation for the validation set
test_dev = abs(np.squeeze(pred_test)-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
rms_dev = sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
# Out:
# Mean absolute deviation: 0.008064226464491632
# RMS deviation: 0.01106110357692332
