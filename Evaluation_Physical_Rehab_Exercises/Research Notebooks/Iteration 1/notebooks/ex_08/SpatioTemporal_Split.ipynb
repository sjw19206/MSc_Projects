# %% [markdown]
# The network predicts quality scores for the individual repetitions for Exercise 1 - Deep Squat. The input to the network are the raw measurement data with 117 dimensions.

# %%
# Import libraries and functions

from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility

import csv
import os,random

# The code is run on a CPU

from keras.models import Model
from keras.layers import Input, Conv1D, LSTM, Dense, Dropout, Activation, Flatten, concatenate, UpSampling1D
from keras.callbacks import EarlyStopping
from keras.optimizers import *
from keras.layers import Lambda

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_error
from math import sqrt

import datetime
now = datetime.datetime.now

# %%
timesteps = 240  # number of timesteps
nr = 90   # number of repetitions
n_dim = 117  # dimension of the data sequences

# %%
import DataViconLoad   # Import the data
Correct_data, Correct_label, Incorrect_data, Incorrect_label = DataViconLoad.load_data()

# Print the size of the data 
print(Correct_data.shape, 'correct sequences')
print(Correct_label.shape, 'correct labels')
print(Incorrect_data.shape, 'incorrect sequences')
print(Incorrect_label.shape, 'incorrect labels')
# Out:
# (90, 240, 117) correct sequences
# (90, 1) correct labels
# (90, 240, 117) incorrect sequences
# (90, 1) incorrect labels

# %%
# Split the data into training and validation sets
# Training set: 60%
# Testing set: 20%
# Validation set: 20%

# Sample random indices
trainidx1 = random.sample(range(0,Correct_data.shape[0]),int(nr*0.6))
trainidx2 = random.sample(range(0,Incorrect_data.shape[0]),int(nr*0.6))

tempidx1 = np.setdiff1d(np.arange(0,nr,1),trainidx1)
tempidx2 = np.setdiff1d(np.arange(0,nr,1),trainidx2)

valididx1 = tempidx1[::2] 
valididx2 = tempidx1[1::2]

testidx1 = tempidx2[1::2]
testidx2 = tempidx2[::2]


# Training set: data and labels
train_x = np.concatenate((Correct_data[trainidx1,:,:],Incorrect_data[trainidx2,:,:]))
print(train_x.shape, 'training data')
train_y = np.concatenate((np.squeeze(Correct_label[trainidx1]),np.squeeze(Incorrect_label[trainidx2])))
print(train_y.shape, 'training labels')


# Testing set: data and labels
test_x = np.concatenate((Correct_data[testidx1,:,:],Incorrect_data[testidx2,:,:]))
print(test_x.shape, 'testing data')
test_y = np.concatenate((np.squeeze(Correct_label[testidx1]),np.squeeze(Incorrect_label[testidx2])))
print(test_y.shape, 'testing labels')

# Validation set: data and labels
valid_x = np.concatenate((Correct_data[valididx1,:,:],Incorrect_data[valididx2,:,:]))
print(valid_x.shape, 'validation data')
valid_y = np.concatenate((np.squeeze(Correct_label[valididx1]),np.squeeze(Incorrect_label[valididx2])))
print(valid_y.shape, 'validation labels')
# Out:
# (108, 240, 117) training data
# (108,) training labels
# (36, 240, 117) testing data
# (36,) testing labels
# (36, 240, 117) validation data
# (36,) validation labels

# %%
# Plot the first and last sequence in the training and validation sets
plt.figure(figsize = (14,4))
plt.subplot(2,2,1)
plt.plot(train_x[0])
plt.title('First Train Sequence')
plt.subplot(2,2,2)
plt.plot(train_x[-1])
plt.title('Last Train Sequence')
plt.subplot(2,2,3)
plt.plot(valid_x[0])
plt.title('First Validation Sequence')
plt.subplot(2,2,4)
plt.plot(valid_x[-1])
plt.title('Last Validation Sequence')
plt.tight_layout()
plt.show()

# %%
# Reduce the data length by a factor of 2, 4, and 8 
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
train_x_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
valid_x_2 = np.zeros(train_x_2.shape)
test_x_2 = np.zeros(train_x_2.shape)

train_x_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
valid_x_4 = np.zeros(train_x_4.shape)
test_x_4 = np.zeros(train_x_4.shape)

train_x_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
valid_x_8 = np.zeros(train_x_8.shape)
test_x_8 = np.zeros(train_x_8.shape)

train_x_2 = train_x[:,::2,:]
valid_x_2 = valid_x[:,::2,:]
test_x_2 = test_x[:,::2,:]

train_x_4 = train_x[:,::4,:]
valid_x_4 = valid_x[:,::4,:]
test_x_4 = test_x[:,::4,:]

train_x_8 = train_x[:,::8,:]
valid_x_8 = valid_x[:,::8,:]
test_x_8 = test_x[:,::8,:]

# %%
# Code to re-order the 117 dimensional skeleton data from the Vicon optical tracker into trunk, left arm, right arm, left leg and right leg
def reorder_data(x):
    X_trunk = np.zeros((x.shape[0],x.shape[1],12))
    X_left_arm = np.zeros((x.shape[0],x.shape[1],18))
    X_right_arm = np.zeros((x.shape[0],x.shape[1],18))
    X_left_leg = np.zeros((x.shape[0],x.shape[1],21))
    X_right_leg = np.zeros((x.shape[0],x.shape[1],21))
    X_trunk =  np.concatenate((x[:,:,15:18], x[:,:,18:21], x[:,:,24:27], x[:,:,27:30]), axis = 2)
    X_left_arm = np.concatenate((x[:,:,81:84], x[:,:,87:90], x[:,:,93:96], x[:,:,99:102], x[:,:,105:108], x[:,:,111:114]), axis = 2)
    X_right_arm = np.concatenate((x[:,:,84:87], x[:,:,90:93], x[:,:,96:99], x[:,:,102:105], x[:,:,108:111], x[:,:,114:117]), axis = 2)  
    X_left_leg = np.concatenate((x[:,:,33:36], x[:,:,39:42], x[:,:,45:48], x[:,:,51:54], x[:,:,57:60], x[:,:,63:66], x[:,:,69:72]), axis = 2)
    X_right_leg = np.concatenate((x[:,:,36:39], x[:,:,42:45], x[:,:,48:51], x[:,:,54:57], x[:,:,60:63], x[:,:,66:69], x[:,:,72:75]), axis = 2)
    x_segmented = np.concatenate((X_trunk, X_right_arm, X_left_arm, X_right_leg, X_left_leg),axis = -1)
    return x_segmented

# %%
# Reorder the data dimensions to correspond to the five body parts
trainx =  reorder_data(train_x)
validx =  reorder_data(valid_x)
testx =  reorder_data(test_x)

trainx_2 =  reorder_data(train_x_2)
validx_2 =  reorder_data(valid_x_2)
testx_2 =  reorder_data(test_x_2)

trainx_4 =  reorder_data(train_x_4)
validx_4 =  reorder_data(valid_x_4)
testx_4 =  reorder_data(test_x_4)

trainx_8 =  reorder_data(train_x_8)
validx_8 =  reorder_data(valid_x_8)
testx_8 =  reorder_data(test_x_8)

# %%
# Define a multibranch convolutional Inception-like block
def MultiBranchConv1D(input, filters1, kernel_size1, strides1, strides2):
    print('shape of input: ', input.shape)
    x1 = Conv1D(filters=filters1, kernel_size=kernel_size1+2, strides=strides1, padding='same', activation='relu')(input)
    x1 = Dropout(0.25)(x1)
    x2 = Conv1D(filters=filters1, kernel_size=kernel_size1+6, strides=strides1, padding='same', activation='relu')(input)
    x2 = Dropout(0.25)(x2)
    x3 = Conv1D(filters=filters1, kernel_size=kernel_size1+12, strides=strides1, padding='same', activation='relu')(input)
    x3 = Dropout(0.25)(x3)
    y1 = concatenate([x1, x2, x3], axis=-1)

    x4 = Conv1D(filters=filters1, kernel_size=kernel_size1, strides=strides2, padding='same', activation='relu')(y1)
    x4 = Dropout(0.25)(x4)
    x5 = Conv1D(filters=filters1, kernel_size=kernel_size1+2, strides=strides2, padding='same', activation='relu')(y1)
    x5 = Dropout(0.25)(x5)
    x6 = Conv1D(filters=filters1, kernel_size=kernel_size1+4, strides=strides2, padding='same', activation='relu')(y1)
    x6 = Dropout(0.25)(x6)
    x = concatenate([x4, x5, x6], axis=-1)
    print('shape of x: ', x.shape)
    return x

# %%
# Define a temporal pyramid network
def TempPyramid(input_f, input_2, input_4, input_8, seq_len, n_dims):
    
    #### Full scale sequences
    conv1 = MultiBranchConv1D(input_f, 64, 3, 2, 2)
    
    #### Half scale sequences
    conv2 = MultiBranchConv1D(input_2, 64, 3, 2, 1)

    #### Quarter scale sequences
    conv3 = MultiBranchConv1D(input_4, 64, 3, 1, 1)

    #### Eighth scale sequences
    conv4 = MultiBranchConv1D(input_8, 64, 3, 1, 1)
    upsample1 = UpSampling1D(size = 2)(conv4)

    #### Recurrent layers
    x = concatenate([conv1, conv2, conv3, upsample1], axis=-1)
    return x

# %%
n_dim = 90 # dimension after segmenting the data into body parts
n_dim1 = 12 # trunk dimension
n_dim2 = 18 # arms dimension
n_dim3 = 21 # legs dimension

# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps, n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:12])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 12:30])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 30:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:69])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 69:90])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:12])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 12:30])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 30:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:69])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 69:90])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:12])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 12:30])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 30:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:69])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 69:90])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:12])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 12:30])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 30:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:69])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 69:90])(seq_input_8)

concat_trunk = TempPyramid(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8, timesteps, n_dim1)
concat_left_arm = TempPyramid(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8, timesteps, n_dim2)
concat_right_arm = TempPyramid(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8, timesteps, n_dim2)
concat_left_leg = TempPyramid(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8, timesteps, n_dim3)
concat_right_leg = TempPyramid(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8, timesteps, n_dim3)


print('concat_trunk: ', concat_trunk.shape)
print('concat_left_arm: ', concat_left_arm.shape)
print('concat_right_arm: ', concat_right_arm.shape)
print('concat_left_leg: ', concat_left_leg.shape)
print('concat_right_leg: ', concat_right_leg.shape)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

rec = LSTM(80, return_sequences=True)(concat)
rec1 = LSTM(40, return_sequences=True)(rec)
rec1 = LSTM(40, return_sequences=True)(rec1)
rec2 = LSTM(80)(rec1)

out = Dense(1, activation = 'sigmoid')(rec2)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)

model.compile(loss='binary_crossentropy', optimizer= Adam(learning_rate=0.0001))
# Out:
# shape of input:  (None, 240, 12)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 120, 12)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 60, 12)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 30, 12)
# shape of x:  (None, 30, 192)
# shape of input:  (None, 240, 18)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 120, 18)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 60, 18)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 30, 18)
# shape of x:  (None, 30, 192)
# shape of input:  (None, 240, 18)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 120, 18)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 60, 18)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 30, 18)
# shape of x:  (None, 30, 192)
# shape of input:  (None, 240, 21)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 120, 21)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 60, 21)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 30, 21)
# shape of x:  (None, 30, 192)
# shape of input:  (None, 240, 21)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 120, 21)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 60, 21)
# shape of x:  (None, 60, 192)
# shape of input:  (None, 30, 21)
# shape of x:  (None, 30, 192)
# concat_trunk:  (None, 60, 768)
# concat_left_arm:  (None, 60, 768)
# concat_right_arm:  (None, 60, 768)
# concat_left_leg:  (None, 60, 768)
# concat_right_leg:  (None, 60, 768)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  eighth_scale (InputLayer)      [(None, 30, 90)]     0           []
#
#  full_scale (InputLayer)        [(None, 240, 90)]    0           []
#
#  half_scale (InputLayer)        [(None, 120, 90)]    0           []
#
#  quarter_scale (InputLayer)     [(None, 60, 90)]     0           []
#
#  lambda_15 (Lambda)             (None, 30, 12)       0           ['eighth_scale[0][0]']
#
#  lambda_16 (Lambda)             (None, 30, 18)       0           ['eighth_scale[0][0]']
#
#  lambda_17 (Lambda)             (None, 30, 18)       0           ['eighth_scale[0][0]']
#
#  lambda_18 (Lambda)             (None, 30, 21)       0           ['eighth_scale[0][0]']
#
#  lambda_19 (Lambda)             (None, 30, 21)       0           ['eighth_scale[0][0]']
#
#  lambda (Lambda)                (None, 240, 12)      0           ['full_scale[0][0]']
#
#  lambda_5 (Lambda)              (None, 120, 12)      0           ['half_scale[0][0]']
#
#  lambda_10 (Lambda)             (None, 60, 12)       0           ['quarter_scale[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 30, 64)       3904        ['lambda_15[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 30, 64)       6976        ['lambda_15[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 30, 64)       11584       ['lambda_15[0][0]']
#
#  lambda_1 (Lambda)              (None, 240, 18)      0           ['full_scale[0][0]']
#
#  lambda_6 (Lambda)              (None, 120, 18)      0           ['half_scale[0][0]']
#
#  lambda_11 (Lambda)             (None, 60, 18)       0           ['quarter_scale[0][0]']
#
#  conv1d_42 (Conv1D)             (None, 30, 64)       5824        ['lambda_16[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 30, 64)       10432       ['lambda_16[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 30, 64)       17344       ['lambda_16[0][0]']
#
#  lambda_2 (Lambda)              (None, 240, 18)      0           ['full_scale[0][0]']
#
#  lambda_7 (Lambda)              (None, 120, 18)      0           ['half_scale[0][0]']
#
#  lambda_12 (Lambda)             (None, 60, 18)       0           ['quarter_scale[0][0]']
#
#  conv1d_66 (Conv1D)             (None, 30, 64)       5824        ['lambda_17[0][0]']
#
#  conv1d_67 (Conv1D)             (None, 30, 64)       10432       ['lambda_17[0][0]']
#
#  conv1d_68 (Conv1D)             (None, 30, 64)       17344       ['lambda_17[0][0]']
#
#  lambda_3 (Lambda)              (None, 240, 21)      0           ['full_scale[0][0]']
#
#  lambda_8 (Lambda)              (None, 120, 21)      0           ['half_scale[0][0]']
#
#  lambda_13 (Lambda)             (None, 60, 21)       0           ['quarter_scale[0][0]']
#
#  conv1d_90 (Conv1D)             (None, 30, 64)       6784        ['lambda_18[0][0]']
#
#  conv1d_91 (Conv1D)             (None, 30, 64)       12160       ['lambda_18[0][0]']
#
#  conv1d_92 (Conv1D)             (None, 30, 64)       20224       ['lambda_18[0][0]']
#
#  lambda_4 (Lambda)              (None, 240, 21)      0           ['full_scale[0][0]']
#
#  lambda_9 (Lambda)              (None, 120, 21)      0           ['half_scale[0][0]']
#
#  lambda_14 (Lambda)             (None, 60, 21)       0           ['quarter_scale[0][0]']
#
#  conv1d_114 (Conv1D)            (None, 30, 64)       6784        ['lambda_19[0][0]']
#
#  conv1d_115 (Conv1D)            (None, 30, 64)       12160       ['lambda_19[0][0]']
#
#  conv1d_116 (Conv1D)            (None, 30, 64)       20224       ['lambda_19[0][0]']
#
#  conv1d (Conv1D)                (None, 120, 64)      3904        ['lambda[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 120, 64)      6976        ['lambda[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 120, 64)      11584       ['lambda[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 60, 64)       3904        ['lambda_5[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 60, 64)       6976        ['lambda_5[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 60, 64)       11584       ['lambda_5[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 60, 64)       3904        ['lambda_10[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 60, 64)       6976        ['lambda_10[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 60, 64)       11584       ['lambda_10[0][0]']
#
#  dropout_18 (Dropout)           (None, 30, 64)       0           ['conv1d_18[0][0]']
#
#  dropout_19 (Dropout)           (None, 30, 64)       0           ['conv1d_19[0][0]']
#
#  dropout_20 (Dropout)           (None, 30, 64)       0           ['conv1d_20[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 120, 64)      5824        ['lambda_1[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 120, 64)      10432       ['lambda_1[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 120, 64)      17344       ['lambda_1[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 60, 64)       5824        ['lambda_6[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 60, 64)       10432       ['lambda_6[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 60, 64)       17344       ['lambda_6[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 60, 64)       5824        ['lambda_11[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 60, 64)       10432       ['lambda_11[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 60, 64)       17344       ['lambda_11[0][0]']
#
#  dropout_42 (Dropout)           (None, 30, 64)       0           ['conv1d_42[0][0]']
#
#  dropout_43 (Dropout)           (None, 30, 64)       0           ['conv1d_43[0][0]']
#
#  dropout_44 (Dropout)           (None, 30, 64)       0           ['conv1d_44[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 120, 64)      5824        ['lambda_2[0][0]']
#
#  conv1d_49 (Conv1D)             (None, 120, 64)      10432       ['lambda_2[0][0]']
#
#  conv1d_50 (Conv1D)             (None, 120, 64)      17344       ['lambda_2[0][0]']
#
#  conv1d_54 (Conv1D)             (None, 60, 64)       5824        ['lambda_7[0][0]']
#
#  conv1d_55 (Conv1D)             (None, 60, 64)       10432       ['lambda_7[0][0]']
#
#  conv1d_56 (Conv1D)             (None, 60, 64)       17344       ['lambda_7[0][0]']
#
#  conv1d_60 (Conv1D)             (None, 60, 64)       5824        ['lambda_12[0][0]']
#
#  conv1d_61 (Conv1D)             (None, 60, 64)       10432       ['lambda_12[0][0]']
#
#  conv1d_62 (Conv1D)             (None, 60, 64)       17344       ['lambda_12[0][0]']
#
#  dropout_66 (Dropout)           (None, 30, 64)       0           ['conv1d_66[0][0]']
#
#  dropout_67 (Dropout)           (None, 30, 64)       0           ['conv1d_67[0][0]']
#
#  dropout_68 (Dropout)           (None, 30, 64)       0           ['conv1d_68[0][0]']
#
#  conv1d_72 (Conv1D)             (None, 120, 64)      6784        ['lambda_3[0][0]']
#
#  conv1d_73 (Conv1D)             (None, 120, 64)      12160       ['lambda_3[0][0]']
#
#  conv1d_74 (Conv1D)             (None, 120, 64)      20224       ['lambda_3[0][0]']
#
#  conv1d_78 (Conv1D)             (None, 60, 64)       6784        ['lambda_8[0][0]']
#
#  conv1d_79 (Conv1D)             (None, 60, 64)       12160       ['lambda_8[0][0]']
#
#  conv1d_80 (Conv1D)             (None, 60, 64)       20224       ['lambda_8[0][0]']
#
#  conv1d_84 (Conv1D)             (None, 60, 64)       6784        ['lambda_13[0][0]']
#
#  conv1d_85 (Conv1D)             (None, 60, 64)       12160       ['lambda_13[0][0]']
#
#  conv1d_86 (Conv1D)             (None, 60, 64)       20224       ['lambda_13[0][0]']
#
#  dropout_90 (Dropout)           (None, 30, 64)       0           ['conv1d_90[0][0]']
#
#  dropout_91 (Dropout)           (None, 30, 64)       0           ['conv1d_91[0][0]']
#
#  dropout_92 (Dropout)           (None, 30, 64)       0           ['conv1d_92[0][0]']
#
#  conv1d_96 (Conv1D)             (None, 120, 64)      6784        ['lambda_4[0][0]']
#
#  conv1d_97 (Conv1D)             (None, 120, 64)      12160       ['lambda_4[0][0]']
#
#  conv1d_98 (Conv1D)             (None, 120, 64)      20224       ['lambda_4[0][0]']
#
#  conv1d_102 (Conv1D)            (None, 60, 64)       6784        ['lambda_9[0][0]']
#
#  conv1d_103 (Conv1D)            (None, 60, 64)       12160       ['lambda_9[0][0]']
#
#  conv1d_104 (Conv1D)            (None, 60, 64)       20224       ['lambda_9[0][0]']
#
#  conv1d_108 (Conv1D)            (None, 60, 64)       6784        ['lambda_14[0][0]']
#
#  conv1d_109 (Conv1D)            (None, 60, 64)       12160       ['lambda_14[0][0]']
#
#  conv1d_110 (Conv1D)            (None, 60, 64)       20224       ['lambda_14[0][0]']
#
#  dropout_114 (Dropout)          (None, 30, 64)       0           ['conv1d_114[0][0]']
#
#  dropout_115 (Dropout)          (None, 30, 64)       0           ['conv1d_115[0][0]']
#
#  dropout_116 (Dropout)          (None, 30, 64)       0           ['conv1d_116[0][0]']
#
#  dropout (Dropout)              (None, 120, 64)      0           ['conv1d[0][0]']
#
#  dropout_1 (Dropout)            (None, 120, 64)      0           ['conv1d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 120, 64)      0           ['conv1d_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 60, 64)       0           ['conv1d_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 60, 64)       0           ['conv1d_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 60, 64)       0           ['conv1d_8[0][0]']
#
#  dropout_12 (Dropout)           (None, 60, 64)       0           ['conv1d_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 60, 64)       0           ['conv1d_13[0][0]']
#
#  dropout_14 (Dropout)           (None, 60, 64)       0           ['conv1d_14[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 30, 192)      0           ['dropout_18[0][0]',
#                                                                   'dropout_19[0][0]',
#                                                                   'dropout_20[0][0]']
#
#  dropout_24 (Dropout)           (None, 120, 64)      0           ['conv1d_24[0][0]']
#
#  dropout_25 (Dropout)           (None, 120, 64)      0           ['conv1d_25[0][0]']
#
#  dropout_26 (Dropout)           (None, 120, 64)      0           ['conv1d_26[0][0]']
#
#  dropout_30 (Dropout)           (None, 60, 64)       0           ['conv1d_30[0][0]']
#
#  dropout_31 (Dropout)           (None, 60, 64)       0           ['conv1d_31[0][0]']
#
#  dropout_32 (Dropout)           (None, 60, 64)       0           ['conv1d_32[0][0]']
#
#  dropout_36 (Dropout)           (None, 60, 64)       0           ['conv1d_36[0][0]']
#
#  dropout_37 (Dropout)           (None, 60, 64)       0           ['conv1d_37[0][0]']
#
#  dropout_38 (Dropout)           (None, 60, 64)       0           ['conv1d_38[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 30, 192)      0           ['dropout_42[0][0]',
#                                                                   'dropout_43[0][0]',
#                                                                   'dropout_44[0][0]']
#
#  dropout_48 (Dropout)           (None, 120, 64)      0           ['conv1d_48[0][0]']
#
#  dropout_49 (Dropout)           (None, 120, 64)      0           ['conv1d_49[0][0]']
#
#  dropout_50 (Dropout)           (None, 120, 64)      0           ['conv1d_50[0][0]']
#
#  dropout_54 (Dropout)           (None, 60, 64)       0           ['conv1d_54[0][0]']
#
#  dropout_55 (Dropout)           (None, 60, 64)       0           ['conv1d_55[0][0]']
#
#  dropout_56 (Dropout)           (None, 60, 64)       0           ['conv1d_56[0][0]']
#
#  dropout_60 (Dropout)           (None, 60, 64)       0           ['conv1d_60[0][0]']
#
#  dropout_61 (Dropout)           (None, 60, 64)       0           ['conv1d_61[0][0]']
#
#  dropout_62 (Dropout)           (None, 60, 64)       0           ['conv1d_62[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 30, 192)      0           ['dropout_66[0][0]',
#                                                                   'dropout_67[0][0]',
#                                                                   'dropout_68[0][0]']
#
#  dropout_72 (Dropout)           (None, 120, 64)      0           ['conv1d_72[0][0]']
#
#  dropout_73 (Dropout)           (None, 120, 64)      0           ['conv1d_73[0][0]']
#
#  dropout_74 (Dropout)           (None, 120, 64)      0           ['conv1d_74[0][0]']
#
#  dropout_78 (Dropout)           (None, 60, 64)       0           ['conv1d_78[0][0]']
#
#  dropout_79 (Dropout)           (None, 60, 64)       0           ['conv1d_79[0][0]']
#
#  dropout_80 (Dropout)           (None, 60, 64)       0           ['conv1d_80[0][0]']
#
#  dropout_84 (Dropout)           (None, 60, 64)       0           ['conv1d_84[0][0]']
#
#  dropout_85 (Dropout)           (None, 60, 64)       0           ['conv1d_85[0][0]']
#
#  dropout_86 (Dropout)           (None, 60, 64)       0           ['conv1d_86[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 30, 192)      0           ['dropout_90[0][0]',
#                                                                   'dropout_91[0][0]',
#                                                                   'dropout_92[0][0]']
#
#  dropout_96 (Dropout)           (None, 120, 64)      0           ['conv1d_96[0][0]']
#
#  dropout_97 (Dropout)           (None, 120, 64)      0           ['conv1d_97[0][0]']
#
#  dropout_98 (Dropout)           (None, 120, 64)      0           ['conv1d_98[0][0]']
#
#  dropout_102 (Dropout)          (None, 60, 64)       0           ['conv1d_102[0][0]']
#
#  dropout_103 (Dropout)          (None, 60, 64)       0           ['conv1d_103[0][0]']
#
#  dropout_104 (Dropout)          (None, 60, 64)       0           ['conv1d_104[0][0]']
#
#  dropout_108 (Dropout)          (None, 60, 64)       0           ['conv1d_108[0][0]']
#
#  dropout_109 (Dropout)          (None, 60, 64)       0           ['conv1d_109[0][0]']
#
#  dropout_110 (Dropout)          (None, 60, 64)       0           ['conv1d_110[0][0]']
#
#  concatenate_42 (Concatenate)   (None, 30, 192)      0           ['dropout_114[0][0]',
#                                                                   'dropout_115[0][0]',
#                                                                   'dropout_116[0][0]']
#
#  concatenate (Concatenate)      (None, 120, 192)     0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 60, 192)      0           ['dropout_6[0][0]',
#                                                                   'dropout_7[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 60, 192)      0           ['dropout_12[0][0]',
#                                                                   'dropout_13[0][0]',
#                                                                   'dropout_14[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 30, 64)       36928       ['concatenate_6[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 30, 64)       61504       ['concatenate_6[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 30, 64)       86080       ['concatenate_6[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 120, 192)     0           ['dropout_24[0][0]',
#                                                                   'dropout_25[0][0]',
#                                                                   'dropout_26[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 60, 192)      0           ['dropout_30[0][0]',
#                                                                   'dropout_31[0][0]',
#                                                                   'dropout_32[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 60, 192)      0           ['dropout_36[0][0]',
#                                                                   'dropout_37[0][0]',
#                                                                   'dropout_38[0][0]']
#
#  conv1d_45 (Conv1D)             (None, 30, 64)       36928       ['concatenate_15[0][0]']
#
#  conv1d_46 (Conv1D)             (None, 30, 64)       61504       ['concatenate_15[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 30, 64)       86080       ['concatenate_15[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 120, 192)     0           ['dropout_48[0][0]',
#                                                                   'dropout_49[0][0]',
#                                                                   'dropout_50[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 60, 192)      0           ['dropout_54[0][0]',
#                                                                   'dropout_55[0][0]',
#                                                                   'dropout_56[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 60, 192)      0           ['dropout_60[0][0]',
#                                                                   'dropout_61[0][0]',
#                                                                   'dropout_62[0][0]']
#
#  conv1d_69 (Conv1D)             (None, 30, 64)       36928       ['concatenate_24[0][0]']
#
#  conv1d_70 (Conv1D)             (None, 30, 64)       61504       ['concatenate_24[0][0]']
#
#  conv1d_71 (Conv1D)             (None, 30, 64)       86080       ['concatenate_24[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 120, 192)     0           ['dropout_72[0][0]',
#                                                                   'dropout_73[0][0]',
#                                                                   'dropout_74[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 60, 192)      0           ['dropout_78[0][0]',
#                                                                   'dropout_79[0][0]',
#                                                                   'dropout_80[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 60, 192)      0           ['dropout_84[0][0]',
#                                                                   'dropout_85[0][0]',
#                                                                   'dropout_86[0][0]']
#
#  conv1d_93 (Conv1D)             (None, 30, 64)       36928       ['concatenate_33[0][0]']
#
#  conv1d_94 (Conv1D)             (None, 30, 64)       61504       ['concatenate_33[0][0]']
#
#  conv1d_95 (Conv1D)             (None, 30, 64)       86080       ['concatenate_33[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 120, 192)     0           ['dropout_96[0][0]',
#                                                                   'dropout_97[0][0]',
#                                                                   'dropout_98[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 60, 192)      0           ['dropout_102[0][0]',
#                                                                   'dropout_103[0][0]',
#                                                                   'dropout_104[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 60, 192)      0           ['dropout_108[0][0]',
#                                                                   'dropout_109[0][0]',
#                                                                   'dropout_110[0][0]']
#
#  conv1d_117 (Conv1D)            (None, 30, 64)       36928       ['concatenate_42[0][0]']
#
#  conv1d_118 (Conv1D)            (None, 30, 64)       61504       ['concatenate_42[0][0]']
#
#  conv1d_119 (Conv1D)            (None, 30, 64)       86080       ['concatenate_42[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 60, 64)       36928       ['concatenate[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 60, 64)       61504       ['concatenate[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 60, 64)       86080       ['concatenate[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 60, 64)       36928       ['concatenate_2[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 60, 64)       61504       ['concatenate_2[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 60, 64)       86080       ['concatenate_2[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 60, 64)       36928       ['concatenate_4[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 60, 64)       61504       ['concatenate_4[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 60, 64)       86080       ['concatenate_4[0][0]']
#
#  dropout_21 (Dropout)           (None, 30, 64)       0           ['conv1d_21[0][0]']
#
#  dropout_22 (Dropout)           (None, 30, 64)       0           ['conv1d_22[0][0]']
#
#  dropout_23 (Dropout)           (None, 30, 64)       0           ['conv1d_23[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 60, 64)       36928       ['concatenate_9[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 60, 64)       61504       ['concatenate_9[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 60, 64)       86080       ['concatenate_9[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 60, 64)       36928       ['concatenate_11[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 60, 64)       61504       ['concatenate_11[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 60, 64)       86080       ['concatenate_11[0][0]']
#
#  conv1d_39 (Conv1D)             (None, 60, 64)       36928       ['concatenate_13[0][0]']
#
#  conv1d_40 (Conv1D)             (None, 60, 64)       61504       ['concatenate_13[0][0]']
#
#  conv1d_41 (Conv1D)             (None, 60, 64)       86080       ['concatenate_13[0][0]']
#
#  dropout_45 (Dropout)           (None, 30, 64)       0           ['conv1d_45[0][0]']
#
#  dropout_46 (Dropout)           (None, 30, 64)       0           ['conv1d_46[0][0]']
#
#  dropout_47 (Dropout)           (None, 30, 64)       0           ['conv1d_47[0][0]']
#
#  conv1d_51 (Conv1D)             (None, 60, 64)       36928       ['concatenate_18[0][0]']
#
#  conv1d_52 (Conv1D)             (None, 60, 64)       61504       ['concatenate_18[0][0]']
#
#  conv1d_53 (Conv1D)             (None, 60, 64)       86080       ['concatenate_18[0][0]']
#
#  conv1d_57 (Conv1D)             (None, 60, 64)       36928       ['concatenate_20[0][0]']
#
#  conv1d_58 (Conv1D)             (None, 60, 64)       61504       ['concatenate_20[0][0]']
#
#  conv1d_59 (Conv1D)             (None, 60, 64)       86080       ['concatenate_20[0][0]']
#
#  conv1d_63 (Conv1D)             (None, 60, 64)       36928       ['concatenate_22[0][0]']
#
#  conv1d_64 (Conv1D)             (None, 60, 64)       61504       ['concatenate_22[0][0]']
#
#  conv1d_65 (Conv1D)             (None, 60, 64)       86080       ['concatenate_22[0][0]']
#
#  dropout_69 (Dropout)           (None, 30, 64)       0           ['conv1d_69[0][0]']
#
#  dropout_70 (Dropout)           (None, 30, 64)       0           ['conv1d_70[0][0]']
#
#  dropout_71 (Dropout)           (None, 30, 64)       0           ['conv1d_71[0][0]']
#
#  conv1d_75 (Conv1D)             (None, 60, 64)       36928       ['concatenate_27[0][0]']
#
#  conv1d_76 (Conv1D)             (None, 60, 64)       61504       ['concatenate_27[0][0]']
#
#  conv1d_77 (Conv1D)             (None, 60, 64)       86080       ['concatenate_27[0][0]']
#
#  conv1d_81 (Conv1D)             (None, 60, 64)       36928       ['concatenate_29[0][0]']
#
#  conv1d_82 (Conv1D)             (None, 60, 64)       61504       ['concatenate_29[0][0]']
#
#  conv1d_83 (Conv1D)             (None, 60, 64)       86080       ['concatenate_29[0][0]']
# ...
#                                                                   'dropout_70[0][0]',
#                                                                   'dropout_71[0][0]']
#
#  dropout_75 (Dropout)           (None, 60, 64)       0           ['conv1d_75[0][0]']
#
#  dropout_76 (Dropout)           (None, 60, 64)       0           ['conv1d_76[0][0]']
#
#  dropout_77 (Dropout)           (None, 60, 64)       0           ['conv1d_77[0][0]']
#
#  dropout_81 (Dropout)           (None, 60, 64)       0           ['conv1d_81[0][0]']
#
#  dropout_82 (Dropout)           (None, 60, 64)       0           ['conv1d_82[0][0]']
#
#  dropout_83 (Dropout)           (None, 60, 64)       0           ['conv1d_83[0][0]']
#
#  dropout_87 (Dropout)           (None, 60, 64)       0           ['conv1d_87[0][0]']
#
#  dropout_88 (Dropout)           (None, 60, 64)       0           ['conv1d_88[0][0]']
#
#  dropout_89 (Dropout)           (None, 60, 64)       0           ['conv1d_89[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 30, 192)      0           ['dropout_93[0][0]',
#                                                                   'dropout_94[0][0]',
#                                                                   'dropout_95[0][0]']
#
#  dropout_99 (Dropout)           (None, 60, 64)       0           ['conv1d_99[0][0]']
#
#  dropout_100 (Dropout)          (None, 60, 64)       0           ['conv1d_100[0][0]']
#
#  dropout_101 (Dropout)          (None, 60, 64)       0           ['conv1d_101[0][0]']
#
#  dropout_105 (Dropout)          (None, 60, 64)       0           ['conv1d_105[0][0]']
#
#  dropout_106 (Dropout)          (None, 60, 64)       0           ['conv1d_106[0][0]']
#
#  dropout_107 (Dropout)          (None, 60, 64)       0           ['conv1d_107[0][0]']
#
#  dropout_111 (Dropout)          (None, 60, 64)       0           ['conv1d_111[0][0]']
#
#  dropout_112 (Dropout)          (None, 60, 64)       0           ['conv1d_112[0][0]']
#
#  dropout_113 (Dropout)          (None, 60, 64)       0           ['conv1d_113[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 30, 192)      0           ['dropout_117[0][0]',
#                                                                   'dropout_118[0][0]',
#                                                                   'dropout_119[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 60, 192)      0           ['dropout_3[0][0]',
#                                                                   'dropout_4[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 60, 192)      0           ['dropout_9[0][0]',
#                                                                   'dropout_10[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 60, 192)      0           ['dropout_15[0][0]',
#                                                                   'dropout_16[0][0]',
#                                                                   'dropout_17[0][0]']
#
#  up_sampling1d (UpSampling1D)   (None, 60, 192)      0           ['concatenate_7[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 60, 192)      0           ['dropout_27[0][0]',
#                                                                   'dropout_28[0][0]',
#                                                                   'dropout_29[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 60, 192)      0           ['dropout_33[0][0]',
#                                                                   'dropout_34[0][0]',
#                                                                   'dropout_35[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 60, 192)      0           ['dropout_39[0][0]',
#                                                                   'dropout_40[0][0]',
#                                                                   'dropout_41[0][0]']
#
#  up_sampling1d_1 (UpSampling1D)  (None, 60, 192)     0           ['concatenate_16[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 60, 192)      0           ['dropout_51[0][0]',
#                                                                   'dropout_52[0][0]',
#                                                                   'dropout_53[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 60, 192)      0           ['dropout_57[0][0]',
#                                                                   'dropout_58[0][0]',
#                                                                   'dropout_59[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 60, 192)      0           ['dropout_63[0][0]',
#                                                                   'dropout_64[0][0]',
#                                                                   'dropout_65[0][0]']
#
#  up_sampling1d_2 (UpSampling1D)  (None, 60, 192)     0           ['concatenate_25[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 60, 192)      0           ['dropout_75[0][0]',
#                                                                   'dropout_76[0][0]',
#                                                                   'dropout_77[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 60, 192)      0           ['dropout_81[0][0]',
#                                                                   'dropout_82[0][0]',
#                                                                   'dropout_83[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 60, 192)      0           ['dropout_87[0][0]',
#                                                                   'dropout_88[0][0]',
#                                                                   'dropout_89[0][0]']
#
#  up_sampling1d_3 (UpSampling1D)  (None, 60, 192)     0           ['concatenate_34[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 60, 192)      0           ['dropout_99[0][0]',
#                                                                   'dropout_100[0][0]',
#                                                                   'dropout_101[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 60, 192)      0           ['dropout_105[0][0]',
#                                                                   'dropout_106[0][0]',
#                                                                   'dropout_107[0][0]']
#
#  concatenate_41 (Concatenate)   (None, 60, 192)      0           ['dropout_111[0][0]',
#                                                                   'dropout_112[0][0]',
#                                                                   'dropout_113[0][0]']
#
#  up_sampling1d_4 (UpSampling1D)  (None, 60, 192)     0           ['concatenate_43[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 60, 768)      0           ['concatenate_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'up_sampling1d[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 60, 768)      0           ['concatenate_10[0][0]',
#                                                                   'concatenate_12[0][0]',
#                                                                   'concatenate_14[0][0]',
#                                                                   'up_sampling1d_1[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 60, 768)      0           ['concatenate_19[0][0]',
#                                                                   'concatenate_21[0][0]',
#                                                                   'concatenate_23[0][0]',
#                                                                   'up_sampling1d_2[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 60, 768)      0           ['concatenate_28[0][0]',
#                                                                   'concatenate_30[0][0]',
#                                                                   'concatenate_32[0][0]',
#                                                                   'up_sampling1d_3[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 60, 768)      0           ['concatenate_37[0][0]',
#                                                                   'concatenate_39[0][0]',
#                                                                   'concatenate_41[0][0]',
#                                                                   'up_sampling1d_4[0][0]']
#
#  concatenate_45 (Concatenate)   (None, 60, 3840)     0           ['concatenate_8[0][0]',
#                                                                   'concatenate_17[0][0]',
#                                                                   'concatenate_26[0][0]',
#                                                                   'concatenate_35[0][0]',
#                                                                   'concatenate_44[0][0]']
#
#  lstm (LSTM)                    (None, 60, 80)       1254720     ['concatenate_45[0][0]']
#
#  lstm_1 (LSTM)                  (None, 60, 40)       19360       ['lstm[0][0]']
#
#  lstm_2 (LSTM)                  (None, 60, 40)       12960       ['lstm_1[0][0]']
#
#  lstm_3 (LSTM)                  (None, 80)           38720       ['lstm_2[0][0]']
#
#  dense (Dense)                  (None, 1)            81          ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 5,688,081
# Trainable params: 5,688,081
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
t = now()
    
early_stopping = EarlyStopping(monitor='val_loss', patience = 25)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=10, epochs=500, verbose=1, 
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = [early_stopping])

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/500
# 11/11 [==============================] - 35s 1s/step - loss: 0.6331 - val_loss: 0.5475
# Epoch 2/500
# 11/11 [==============================] - 7s 659ms/step - loss: 0.4715 - val_loss: 0.3941
# Epoch 3/500
# 11/11 [==============================] - 7s 670ms/step - loss: 0.3508 - val_loss: 0.3160
# Epoch 4/500
# 11/11 [==============================] - 7s 649ms/step - loss: 0.3023 - val_loss: 0.2993
# Epoch 5/500
# 11/11 [==============================] - 7s 669ms/step - loss: 0.2980 - val_loss: 0.3009
# Epoch 6/500
# 11/11 [==============================] - 7s 656ms/step - loss: 0.2980 - val_loss: 0.2993
# Epoch 7/500
# 11/11 [==============================] - 8s 691ms/step - loss: 0.2967 - val_loss: 0.2987
# Epoch 8/500
# 11/11 [==============================] - 7s 669ms/step - loss: 0.2963 - val_loss: 0.2984
# Epoch 9/500
# 11/11 [==============================] - 8s 726ms/step - loss: 0.2958 - val_loss: 0.2979
# Epoch 10/500
# 11/11 [==============================] - 7s 670ms/step - loss: 0.2952 - val_loss: 0.2972
# Epoch 11/500
# 11/11 [==============================] - 8s 695ms/step - loss: 0.2943 - val_loss: 0.2964
# Epoch 12/500
# 11/11 [==============================] - 7s 679ms/step - loss: 0.2932 - val_loss: 0.2954
# Epoch 13/500
# 11/11 [==============================] - 8s 693ms/step - loss: 0.2921 - val_loss: 0.2948
# Epoch 14/500
# 11/11 [==============================] - 8s 687ms/step - loss: 0.2913 - val_loss: 0.2945
# Epoch 15/500
# 11/11 [==============================] - 7s 688ms/step - loss: 0.2909 - val_loss: 0.2940
# Epoch 16/500
# 11/11 [==============================] - 8s 723ms/step - loss: 0.2907 - val_loss: 0.2938
# Epoch 17/500
# 11/11 [==============================] - 8s 714ms/step - loss: 0.2906 - val_loss: 0.2941
# Epoch 18/500
# 11/11 [==============================] - 8s 688ms/step - loss: 0.2903 - val_loss: 0.2949
# Epoch 19/500
# 11/11 [==============================] - 7s 683ms/step - loss: 0.2903 - val_loss: 0.2939
# Epoch 20/500
# 11/11 [==============================] - 8s 693ms/step - loss: 0.2900 - val_loss: 0.2937
# Epoch 21/500
# 11/11 [==============================] - 7s 679ms/step - loss: 0.2899 - val_loss: 0.2938
# Epoch 22/500
# 11/11 [==============================] - 8s 699ms/step - loss: 0.2897 - val_loss: 0.2936
# Epoch 23/500
# 11/11 [==============================] - 7s 675ms/step - loss: 0.2897 - val_loss: 0.2936
# Epoch 24/500
# 11/11 [==============================] - 8s 690ms/step - loss: 0.2896 - val_loss: 0.2936
# Epoch 25/500
# 11/11 [==============================] - 8s 697ms/step - loss: 0.2896 - val_loss: 0.2935
# Epoch 26/500
# 11/11 [==============================] - 8s 694ms/step - loss: 0.2895 - val_loss: 0.2935
# Epoch 27/500
# 11/11 [==============================] - 7s 677ms/step - loss: 0.2895 - val_loss: 0.2934
# Epoch 28/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2895 - val_loss: 0.2935
# Epoch 29/500
# 11/11 [==============================] - 8s 688ms/step - loss: 0.2895 - val_loss: 0.2934
# Epoch 30/500
# 11/11 [==============================] - 8s 693ms/step - loss: 0.2896 - val_loss: 0.2934
# Epoch 31/500
# 11/11 [==============================] - 7s 677ms/step - loss: 0.2895 - val_loss: 0.2932
# Epoch 32/500
# 11/11 [==============================] - 7s 686ms/step - loss: 0.2894 - val_loss: 0.2932
# Epoch 33/500
# 11/11 [==============================] - 8s 714ms/step - loss: 0.2894 - val_loss: 0.2932
# Epoch 34/500
# 11/11 [==============================] - 8s 690ms/step - loss: 0.2893 - val_loss: 0.2936
# Epoch 35/500
# 11/11 [==============================] - 8s 687ms/step - loss: 0.2894 - val_loss: 0.2933
# Epoch 36/500
# 11/11 [==============================] - 7s 681ms/step - loss: 0.2894 - val_loss: 0.2934
# Epoch 37/500
# 11/11 [==============================] - 8s 694ms/step - loss: 0.2894 - val_loss: 0.2933
# Epoch 38/500
# 11/11 [==============================] - 8s 691ms/step - loss: 0.2894 - val_loss: 0.2931
# Epoch 39/500
# 11/11 [==============================] - 8s 702ms/step - loss: 0.2893 - val_loss: 0.2931
# Epoch 40/500
# 11/11 [==============================] - 7s 687ms/step - loss: 0.2893 - val_loss: 0.2931
# Epoch 41/500
# 11/11 [==============================] - 8s 722ms/step - loss: 0.2893 - val_loss: 0.2932
# Epoch 42/500
# 11/11 [==============================] - 7s 684ms/step - loss: 0.2893 - val_loss: 0.2931
# Epoch 43/500
# 11/11 [==============================] - 8s 709ms/step - loss: 0.2893 - val_loss: 0.2932
# Epoch 44/500
# 11/11 [==============================] - 7s 676ms/step - loss: 0.2893 - val_loss: 0.2933
# Epoch 45/500
# 11/11 [==============================] - 8s 694ms/step - loss: 0.2893 - val_loss: 0.2931
# Epoch 46/500
# 11/11 [==============================] - 7s 679ms/step - loss: 0.2893 - val_loss: 0.2933
# Epoch 47/500
# 11/11 [==============================] - 8s 694ms/step - loss: 0.2893 - val_loss: 0.2932
# Epoch 48/500
# 11/11 [==============================] - 8s 734ms/step - loss: 0.2893 - val_loss: 0.2932
# Epoch 49/500
# 11/11 [==============================] - 8s 703ms/step - loss: 0.2893 - val_loss: 0.2933
# Epoch 50/500
# 11/11 [==============================] - 7s 674ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 51/500
# 11/11 [==============================] - 8s 699ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 52/500
# 11/11 [==============================] - 7s 678ms/step - loss: 0.2892 - val_loss: 0.2933
# Epoch 53/500
# 11/11 [==============================] - 7s 686ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 54/500
# 11/11 [==============================] - 8s 689ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 55/500
# 11/11 [==============================] - 8s 686ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 56/500
# 11/11 [==============================] - 8s 697ms/step - loss: 0.2892 - val_loss: 0.2933
# Epoch 57/500
# 11/11 [==============================] - 8s 691ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 58/500
# 11/11 [==============================] - 8s 691ms/step - loss: 0.2892 - val_loss: 0.2933
# Epoch 59/500
# 11/11 [==============================] - 7s 683ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 60/500
# 11/11 [==============================] - 8s 698ms/step - loss: 0.2892 - val_loss: 0.2933
# Epoch 61/500
# 11/11 [==============================] - 7s 681ms/step - loss: 0.2893 - val_loss: 0.2933
# Epoch 62/500
# 11/11 [==============================] - 8s 691ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 63/500
# 11/11 [==============================] - 7s 676ms/step - loss: 0.2893 - val_loss: 0.2932
# Epoch 64/500
# 11/11 [==============================] - 8s 714ms/step - loss: 0.2892 - val_loss: 0.2933
# Epoch 65/500
# 11/11 [==============================] - 8s 690ms/step - loss: 0.2892 - val_loss: 0.2931
# Epoch 66/500
# 11/11 [==============================] - 8s 704ms/step - loss: 0.2892 - val_loss: 0.2932
# Epoch 67/500
# 11/11 [==============================] - 8s 731ms/step - loss: 0.2892 - val_loss: 0.2931
# Training time: 0:08:53.886345

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.28916609287261963
# Validation loss 0.29307395219802856

# %%
# Plot the prediction of the model for the training and validation sets
pred_train = model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = model.predict([testx, testx_2, testx_4, testx_8])

plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.1,1.1])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(test_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.1,1.1])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()
plt.savefig('SpatioTemporal_Split.png', dpi=350)
plt.show()
# Out:
# 4/4 [==============================] - 5s 283ms/step
# 2/2 [==============================] - 0s 77ms/step

# %%
# Calculate the cumulative deviation and rms deviation for the validation set
test_dev = abs(np.squeeze(pred_test)-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
rms_dev = sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
# Out:
# Mean absolute deviation: 0.01076170629024506
# RMS deviation: 0.01633734117369548
