# %%
# import

import numpy as np
import pandas as pd
import random

# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping
from keras.optimizers import *

# general
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_error
from math import sqrt

import datetime

# %%
now = datetime.datetime.now
np.random.seed(1337)  # for reproducibility

# %%
timesteps = 240  # number of timesteps
nr = 90   # number of repetitions
n_dim = 117  # dimension of the data sequences

# %%
import DataViconLoad   # Import the data
Correct_data, Correct_label, Incorrect_data, Incorrect_label = DataViconLoad.load_data()

# Print the size of the data 
print(Correct_data.shape, 'correct sequences')
print(Correct_label.shape, 'correct labels')
print(Incorrect_data.shape, 'incorrect sequences')
print(Incorrect_label.shape, 'incorrect labels')
# Out:
# (90, 240, 117) correct sequences
# (90, 1) correct labels
# (90, 240, 117) incorrect sequences
# (90, 1) incorrect labels

# %%
# Split the data into training and validation sets
# Training set: 60%
# Testing set: 20%
# Validation set: 20%

# Sample random indices
trainidx1 = random.sample(range(0,Correct_data.shape[0]),int(nr*0.6))
trainidx2 = random.sample(range(0,Incorrect_data.shape[0]),int(nr*0.6))

tempidx1 = np.setdiff1d(np.arange(0,nr,1),trainidx1)
tempidx2 = np.setdiff1d(np.arange(0,nr,1),trainidx2)

valididx1 = tempidx1[::2] 
valididx2 = tempidx1[1::2]

testidx1 = tempidx2[1::2]
testidx2 = tempidx2[::2]


# Training set: data and labels
train_x = np.concatenate((Correct_data[trainidx1,:,:],Incorrect_data[trainidx2,:,:]))
print(train_x.shape, 'training data')
train_y = np.concatenate((np.squeeze(Correct_label[trainidx1]),np.squeeze(Incorrect_label[trainidx2])))
print(train_y.shape, 'training labels')


# Testing set: data and labels
test_x = np.concatenate((Correct_data[testidx1,:,:],Incorrect_data[testidx2,:,:]))
print(test_x.shape, 'testing data')
test_y = np.concatenate((np.squeeze(Correct_label[testidx1]),np.squeeze(Incorrect_label[testidx2])))
print(test_y.shape, 'testing labels')

# Validation set: data and labels
valid_x = np.concatenate((Correct_data[valididx1,:,:],Incorrect_data[valididx2,:,:]))
print(valid_x.shape, 'validation data')
valid_y = np.concatenate((np.squeeze(Correct_label[valididx1]),np.squeeze(Incorrect_label[valididx2])))
print(valid_y.shape, 'validation labels')
# Out:
# (108, 240, 117) training data
# (108,) training labels
# (36, 240, 117) testing data
# (36,) testing labels
# (36, 240, 117) validation data
# (36,) validation labels

# %%
# Reduce the data length by a factor of 2, 4, and 8 
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
train_x_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_2 = np.zeros(train_x_2.shape)
test_x_2 = np.zeros(train_x_2.shape)

train_x_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_4 = np.zeros(train_x_4.shape)
test_x_4 = np.zeros(train_x_4.shape)

train_x_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]), train_x.shape[2]))
valid_x_8 = np.zeros(train_x_8.shape)
test_x_8 = np.zeros(train_x_8.shape)

train_x_2 = train_x[:,::,:]
valid_x_2 = valid_x[:,::,:]
test_x_2 = test_x[:,::,:]

train_x_4 = train_x[:,::,:]
valid_x_4 = valid_x[:,::,:]
test_x_4 = test_x[:,::,:]

train_x_8 = train_x[:,::,:]
valid_x_8 = valid_x[:,::,:]
test_x_8 = test_x[:,::,:]

# %%
# Code to re-order the 117 dimensional skeleton data from the Vicon optical tracker into trunk, left arm, right arm, left leg and right leg
def reorder_data(x):
    X_trunk = np.zeros((x.shape[0],x.shape[1],12))
    X_left_arm = np.zeros((x.shape[0],x.shape[1],18))
    X_right_arm = np.zeros((x.shape[0],x.shape[1],18))
    X_left_leg = np.zeros((x.shape[0],x.shape[1],21))
    X_right_leg = np.zeros((x.shape[0],x.shape[1],21))
    X_trunk =  np.concatenate((x[:,:,15:18], x[:,:,18:21], x[:,:,24:27], x[:,:,27:30]), axis = 2)
    X_left_arm = np.concatenate((x[:,:,81:84], x[:,:,87:90], x[:,:,93:96], x[:,:,99:102], x[:,:,105:108], x[:,:,111:114]), axis = 2)
    X_right_arm = np.concatenate((x[:,:,84:87], x[:,:,90:93], x[:,:,96:99], x[:,:,102:105], x[:,:,108:111], x[:,:,114:117]), axis = 2)  
    X_left_leg = np.concatenate((x[:,:,33:36], x[:,:,39:42], x[:,:,45:48], x[:,:,51:54], x[:,:,57:60], x[:,:,63:66], x[:,:,69:72]), axis = 2)
    X_right_leg = np.concatenate((x[:,:,36:39], x[:,:,42:45], x[:,:,48:51], x[:,:,54:57], x[:,:,60:63], x[:,:,66:69], x[:,:,72:75]), axis = 2)
    x_segmented = np.concatenate((X_trunk, X_right_arm, X_left_arm, X_right_leg, X_left_leg),axis = -1)
    return x_segmented

# %%
# Reorder the data dimensions to correspond to the five body parts
trainx =  reorder_data(train_x)
validx =  reorder_data(valid_x)
testx =  reorder_data(test_x)

trainx_2 =  reorder_data(train_x_2)
validx_2 =  reorder_data(valid_x_2)
testx_2 =  reorder_data(test_x_2)

trainx_4 =  reorder_data(train_x_4)
validx_4 =  reorder_data(valid_x_4)
testx_4 =  reorder_data(test_x_4)

trainx_8 =  reorder_data(train_x_8)
validx_8 =  reorder_data(valid_x_8)
testx_8 =  reorder_data(test_x_8)

# %%
def createTCNLayers(input, timesteps, n_dim):
        
    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.007,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)
       
    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim1, n_dim2, ndim3):
    
    
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim1)
    
    tcn_2 = createTCNLayers(input_2, timesteps, n_dim2)
    
    
    tcn_3 = createTCNLayers(input_4, timesteps, n_dim2)
        
    tcn_5 = createTCNLayers(input_8, timesteps, n_dim3)
    
    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=-1)
    
    return final_tcn

# %%
n_dim = 90 # dimension after segmenting the data into body parts
n_dim1 = 12 # trunk dimension
n_dim2 = 18 # arms dimension
n_dim3 = 21 # legs dimension

# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps, n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:12])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 12:30])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 30:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:69])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 69:90])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:12])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 12:30])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 30:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:69])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 69:90])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:12])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 12:30])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 30:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:69])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 69:90])(seq_input_4)


#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:12])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 12:30])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 30:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:69])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 69:90])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1, n_dim2, n_dim3)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim1, n_dim2, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim1, n_dim2, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)


out = Dense(1, activation = 'sigmoid')(tcn_layer_final_2)


model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  full_scale (InputLayer)        [(None, 240, 90)]    0           []
#
#  half_scale (InputLayer)        [(None, 240, 90)]    0           []
#
#  quarter_scale (InputLayer)     [(None, 240, 90)]    0           []
#
#  eighth_scale (InputLayer)      [(None, 240, 90)]    0           []
#
#  lambda (Lambda)                (None, 240, 12)      0           ['full_scale[0][0]']
#
#  lambda_5 (Lambda)              (None, 240, 12)      0           ['half_scale[0][0]']
#
#  lambda_10 (Lambda)             (None, 240, 12)      0           ['quarter_scale[0][0]']
#
#  lambda_15 (Lambda)             (None, 240, 12)      0           ['eighth_scale[0][0]']
#
#  lambda_1 (Lambda)              (None, 240, 18)      0           ['full_scale[0][0]']
#
#  lambda_6 (Lambda)              (None, 240, 18)      0           ['half_scale[0][0]']
#
#  lambda_11 (Lambda)             (None, 240, 18)      0           ['quarter_scale[0][0]']
#
#  lambda_16 (Lambda)             (None, 240, 18)      0           ['eighth_scale[0][0]']
#
#  lambda_2 (Lambda)              (None, 240, 18)      0           ['full_scale[0][0]']
#
#  lambda_7 (Lambda)              (None, 240, 18)      0           ['half_scale[0][0]']
#
#  lambda_12 (Lambda)             (None, 240, 18)      0           ['quarter_scale[0][0]']
#
#  lambda_17 (Lambda)             (None, 240, 18)      0           ['eighth_scale[0][0]']
#
#  lambda_3 (Lambda)              (None, 240, 21)      0           ['full_scale[0][0]']
#
#  lambda_8 (Lambda)              (None, 240, 21)      0           ['half_scale[0][0]']
#
#  lambda_13 (Lambda)             (None, 240, 21)      0           ['quarter_scale[0][0]']
#
#  lambda_18 (Lambda)             (None, 240, 21)      0           ['eighth_scale[0][0]']
#
#  lambda_4 (Lambda)              (None, 240, 21)      0           ['full_scale[0][0]']
#
#  lambda_9 (Lambda)              (None, 240, 21)      0           ['half_scale[0][0]']
#
#  lambda_14 (Lambda)             (None, 240, 21)      0           ['quarter_scale[0][0]']
#
#  lambda_19 (Lambda)             (None, 240, 21)      0           ['eighth_scale[0][0]']
#
#  tcn (TCN)                      (None, 240, 12)      5328        ['lambda[0][0]']
#
#  tcn_1 (TCN)                    (None, 240, 12)      5328        ['lambda_5[0][0]']
#
#  tcn_2 (TCN)                    (None, 240, 12)      5328        ['lambda_10[0][0]']
#
#  tcn_3 (TCN)                    (None, 240, 12)      5328        ['lambda_15[0][0]']
#
#  tcn_4 (TCN)                    (None, 240, 12)      5772        ['lambda_1[0][0]']
#
#  tcn_5 (TCN)                    (None, 240, 12)      5772        ['lambda_6[0][0]']
#
#  tcn_6 (TCN)                    (None, 240, 12)      5772        ['lambda_11[0][0]']
#
#  tcn_7 (TCN)                    (None, 240, 12)      5772        ['lambda_16[0][0]']
#
#  tcn_8 (TCN)                    (None, 240, 12)      5772        ['lambda_2[0][0]']
#
#  tcn_9 (TCN)                    (None, 240, 12)      5772        ['lambda_7[0][0]']
#
#  tcn_10 (TCN)                   (None, 240, 12)      5772        ['lambda_12[0][0]']
#
#  tcn_11 (TCN)                   (None, 240, 12)      5772        ['lambda_17[0][0]']
#
#  tcn_12 (TCN)                   (None, 240, 12)      5916        ['lambda_3[0][0]']
#
#  tcn_13 (TCN)                   (None, 240, 12)      5916        ['lambda_8[0][0]']
#
#  tcn_14 (TCN)                   (None, 240, 12)      5916        ['lambda_13[0][0]']
#
#  tcn_15 (TCN)                   (None, 240, 12)      5916        ['lambda_18[0][0]']
#
#  tcn_16 (TCN)                   (None, 240, 12)      5916        ['lambda_4[0][0]']
#
#  tcn_17 (TCN)                   (None, 240, 12)      5916        ['lambda_9[0][0]']
#
#  tcn_18 (TCN)                   (None, 240, 12)      5916        ['lambda_14[0][0]']
#
#  tcn_19 (TCN)                   (None, 240, 12)      5916        ['lambda_19[0][0]']
#
#  concatenate (Concatenate)      (None, 240, 48)      0           ['tcn[0][0]',
#                                                                   'tcn_1[0][0]',
#                                                                   'tcn_2[0][0]',
#                                                                   'tcn_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 240, 48)      0           ['tcn_4[0][0]',
#                                                                   'tcn_5[0][0]',
#                                                                   'tcn_6[0][0]',
#                                                                   'tcn_7[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 240, 48)      0           ['tcn_8[0][0]',
#                                                                   'tcn_9[0][0]',
#                                                                   'tcn_10[0][0]',
#                                                                   'tcn_11[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 240, 48)      0           ['tcn_12[0][0]',
#                                                                   'tcn_13[0][0]',
#                                                                   'tcn_14[0][0]',
#                                                                   'tcn_15[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 240, 48)      0           ['tcn_16[0][0]',
#                                                                   'tcn_17[0][0]',
#                                                                   'tcn_18[0][0]',
#                                                                   'tcn_19[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 240, 240)     0           ['concatenate[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  tcn_20 (TCN)                   (None, 240, 12)      14652       ['concatenate_5[0][0]']
#
#  tcn_21 (TCN)                   (None, 240, 8)       1176        ['tcn_20[0][0]']
#
#  tcn_22 (TCN)                   (None, 6)            546         ['tcn_21[0][0]']
#
#  dense (Dense)                  (None, 1)            7           ['tcn_22[0][0]']
#
# ==================================================================================================
# Total params: 131,197
# Trainable params: 131,101
# Non-trainable params: 96
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0003), loss='mse')

# %%
t = now()
    
early_stopping = EarlyStopping(monitor='val_loss', patience = 55)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=250, verbose=1, 
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = [early_stopping])

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/250
# 16/16 [==============================] - 70s 907ms/step - loss: 0.0087 - val_loss: 0.0051
# Epoch 2/250
# 16/16 [==============================] - 8s 491ms/step - loss: 0.0071 - val_loss: 0.0049
# Epoch 3/250
# 16/16 [==============================] - 8s 494ms/step - loss: 0.0068 - val_loss: 0.0048
# Epoch 4/250
# 16/16 [==============================] - 8s 486ms/step - loss: 0.0079 - val_loss: 0.0041
# Epoch 5/250
# 16/16 [==============================] - 8s 496ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 6/250
# 16/16 [==============================] - 8s 474ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 7/250
# 16/16 [==============================] - 8s 495ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 8/250
# 16/16 [==============================] - 8s 477ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 9/250
# 16/16 [==============================] - 8s 499ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 10/250
# 16/16 [==============================] - 8s 480ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 11/250
# 16/16 [==============================] - 8s 513ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 12/250
# 16/16 [==============================] - 8s 482ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 13/250
# 16/16 [==============================] - 8s 498ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 14/250
# 16/16 [==============================] - 8s 489ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 15/250
# 16/16 [==============================] - 8s 497ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 16/250
# 16/16 [==============================] - 8s 481ms/step - loss: 0.0044 - val_loss: 0.0024
# Epoch 17/250
# 16/16 [==============================] - 8s 503ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 18/250
# 16/16 [==============================] - 8s 482ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 19/250
# 16/16 [==============================] - 8s 495ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 20/250
# 16/16 [==============================] - 8s 484ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 21/250
# 16/16 [==============================] - 8s 505ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 22/250
# 16/16 [==============================] - 8s 493ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 23/250
# 16/16 [==============================] - 8s 495ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 24/250
# 16/16 [==============================] - 8s 484ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 25/250
# 16/16 [==============================] - 8s 493ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 26/250
# 16/16 [==============================] - 8s 485ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 27/250
# 16/16 [==============================] - 8s 497ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 28/250
# 16/16 [==============================] - 8s 481ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 29/250
# 16/16 [==============================] - 8s 491ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 30/250
# 16/16 [==============================] - 8s 489ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 31/250
# 16/16 [==============================] - 8s 495ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 32/250
# 16/16 [==============================] - 8s 488ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 33/250
# 16/16 [==============================] - 8s 494ms/step - loss: 0.0016 - val_loss: 8.2024e-04
# Epoch 34/250
# 16/16 [==============================] - 8s 498ms/step - loss: 0.0016 - val_loss: 6.9086e-04
# Epoch 35/250
# 16/16 [==============================] - 8s 492ms/step - loss: 0.0011 - val_loss: 7.5759e-04
# Epoch 36/250
# 16/16 [==============================] - 8s 500ms/step - loss: 0.0010 - val_loss: 6.1473e-04
# Epoch 37/250
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0014 - val_loss: 6.1247e-04
# Epoch 38/250
# 16/16 [==============================] - 9s 567ms/step - loss: 7.4659e-04 - val_loss: 4.6659e-04
# Epoch 39/250
# 16/16 [==============================] - 9s 536ms/step - loss: 0.0017 - val_loss: 4.2162e-04
# Epoch 40/250
# 16/16 [==============================] - 8s 511ms/step - loss: 0.0018 - val_loss: 4.3061e-04
# Epoch 41/250
# 16/16 [==============================] - 8s 517ms/step - loss: 0.0016 - val_loss: 4.5296e-04
# Epoch 42/250
# 16/16 [==============================] - 8s 514ms/step - loss: 8.7865e-04 - val_loss: 3.7249e-04
# Epoch 43/250
# 16/16 [==============================] - 8s 533ms/step - loss: 0.0017 - val_loss: 2.5503e-04
# Epoch 44/250
# 16/16 [==============================] - 8s 495ms/step - loss: 9.5025e-04 - val_loss: 3.6306e-04
# Epoch 45/250
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0013 - val_loss: 2.2695e-04
# Epoch 46/250
# 16/16 [==============================] - 9s 534ms/step - loss: 0.0012 - val_loss: 2.2935e-04
# Epoch 47/250
# 16/16 [==============================] - 9s 542ms/step - loss: 0.0015 - val_loss: 2.2699e-04
# Epoch 48/250
# 16/16 [==============================] - 8s 525ms/step - loss: 0.0010 - val_loss: 2.3698e-04
# Epoch 49/250
# 16/16 [==============================] - 8s 511ms/step - loss: 0.0014 - val_loss: 2.1360e-04
# Epoch 50/250
# 16/16 [==============================] - 8s 489ms/step - loss: 9.6355e-04 - val_loss: 1.8710e-04
# Epoch 51/250
# 16/16 [==============================] - 9s 535ms/step - loss: 7.9595e-04 - val_loss: 1.6681e-04
# Epoch 52/250
# 16/16 [==============================] - 8s 499ms/step - loss: 7.5273e-04 - val_loss: 1.4190e-04
# Epoch 53/250
# 16/16 [==============================] - 9s 578ms/step - loss: 8.0398e-04 - val_loss: 1.4623e-04
# Epoch 54/250
# 16/16 [==============================] - 8s 518ms/step - loss: 0.0010 - val_loss: 1.3815e-04
# Epoch 55/250
# 16/16 [==============================] - 8s 525ms/step - loss: 0.0011 - val_loss: 1.4257e-04
# Epoch 56/250
# 16/16 [==============================] - 8s 525ms/step - loss: 0.0010 - val_loss: 1.5158e-04
# Epoch 57/250
# 16/16 [==============================] - 8s 486ms/step - loss: 5.5683e-04 - val_loss: 1.8937e-04
# Epoch 58/250
# 16/16 [==============================] - 8s 485ms/step - loss: 0.0010 - val_loss: 2.0652e-04
# Epoch 59/250
# 16/16 [==============================] - 8s 518ms/step - loss: 8.0568e-04 - val_loss: 1.9143e-04
# Epoch 60/250
# 16/16 [==============================] - 9s 541ms/step - loss: 5.1006e-04 - val_loss: 1.6720e-04
# Epoch 61/250
# 16/16 [==============================] - 8s 501ms/step - loss: 6.2137e-04 - val_loss: 1.7574e-04
# Epoch 62/250
# 16/16 [==============================] - 8s 529ms/step - loss: 8.1795e-04 - val_loss: 1.8435e-04
# Epoch 63/250
# 16/16 [==============================] - 8s 517ms/step - loss: 0.0011 - val_loss: 1.7807e-04
# Epoch 64/250
# 16/16 [==============================] - 8s 507ms/step - loss: 7.4618e-04 - val_loss: 1.7061e-04
# Epoch 65/250
# 16/16 [==============================] - 9s 536ms/step - loss: 3.7775e-04 - val_loss: 1.4894e-04
# Epoch 66/250
# 16/16 [==============================] - 8s 522ms/step - loss: 5.6966e-04 - val_loss: 1.5002e-04
# Epoch 67/250
# 16/16 [==============================] - 8s 526ms/step - loss: 4.7062e-04 - val_loss: 1.9039e-04
# Epoch 68/250
# 16/16 [==============================] - 8s 531ms/step - loss: 4.0574e-04 - val_loss: 2.0499e-04
# Epoch 69/250
# 16/16 [==============================] - 8s 504ms/step - loss: 2.5681e-04 - val_loss: 1.9299e-04
# Epoch 70/250
# 16/16 [==============================] - 9s 542ms/step - loss: 8.3128e-04 - val_loss: 2.0409e-04
# Epoch 71/250
# 16/16 [==============================] - 9s 560ms/step - loss: 5.5822e-04 - val_loss: 2.1083e-04
# Epoch 72/250
# 16/16 [==============================] - 9s 560ms/step - loss: 3.7402e-04 - val_loss: 3.7814e-04
# Epoch 73/250
# 16/16 [==============================] - 8s 531ms/step - loss: 6.8303e-04 - val_loss: 2.1483e-04
# Epoch 74/250
# 16/16 [==============================] - 9s 546ms/step - loss: 8.1037e-04 - val_loss: 2.9423e-04
# Epoch 75/250
# 16/16 [==============================] - 9s 543ms/step - loss: 9.9214e-04 - val_loss: 3.0054e-04
# Epoch 76/250
# 16/16 [==============================] - 9s 556ms/step - loss: 3.9563e-04 - val_loss: 3.8619e-04
# Epoch 77/250
# 16/16 [==============================] - 8s 534ms/step - loss: 0.0013 - val_loss: 7.7612e-04
# Epoch 78/250
# 16/16 [==============================] - 8s 510ms/step - loss: 0.0010 - val_loss: 7.8318e-04
# Epoch 79/250
# 16/16 [==============================] - 8s 517ms/step - loss: 9.0770e-04 - val_loss: 4.6125e-04
# Epoch 80/250
# 16/16 [==============================] - 8s 492ms/step - loss: 7.2811e-04 - val_loss: 2.7384e-04
# Epoch 81/250
# 16/16 [==============================] - 8s 511ms/step - loss: 5.2353e-04 - val_loss: 1.9232e-04
# Epoch 82/250
# 16/16 [==============================] - 8s 492ms/step - loss: 3.5540e-04 - val_loss: 1.4328e-04
# Epoch 83/250
# 16/16 [==============================] - 8s 509ms/step - loss: 3.9183e-04 - val_loss: 1.2178e-04
# Epoch 84/250
# 16/16 [==============================] - 8s 503ms/step - loss: 5.0586e-04 - val_loss: 1.1883e-04
# Epoch 85/250
# 16/16 [==============================] - 8s 525ms/step - loss: 0.0012 - val_loss: 1.4686e-04
# Epoch 86/250
# 16/16 [==============================] - 8s 500ms/step - loss: 7.2564e-04 - val_loss: 2.6884e-04
# Epoch 87/250
# 16/16 [==============================] - 9s 543ms/step - loss: 6.3199e-04 - val_loss: 2.9155e-04
# Epoch 88/250
# 16/16 [==============================] - 8s 519ms/step - loss: 9.3535e-04 - val_loss: 3.1193e-04
# Epoch 89/250
# 16/16 [==============================] - 8s 514ms/step - loss: 4.0351e-04 - val_loss: 2.9998e-04
# Epoch 90/250
# 16/16 [==============================] - 8s 487ms/step - loss: 5.7504e-04 - val_loss: 2.6372e-04
# Epoch 91/250
# 16/16 [==============================] - 8s 507ms/step - loss: 9.5490e-04 - val_loss: 2.0552e-04
# Epoch 92/250
# 16/16 [==============================] - 8s 495ms/step - loss: 5.9049e-04 - val_loss: 1.6152e-04
# Epoch 93/250
# 16/16 [==============================] - 8s 511ms/step - loss: 5.8289e-04 - val_loss: 1.3795e-04
# Epoch 94/250
# 16/16 [==============================] - 8s 487ms/step - loss: 3.2523e-04 - val_loss: 1.3849e-04
# Epoch 95/250
# 16/16 [==============================] - 8s 503ms/step - loss: 5.0829e-04 - val_loss: 1.2592e-04
# Epoch 96/250
# 16/16 [==============================] - 8s 485ms/step - loss: 3.8176e-04 - val_loss: 9.7400e-05
# Epoch 97/250
# 16/16 [==============================] - 8s 506ms/step - loss: 4.1379e-04 - val_loss: 8.0112e-05
# Epoch 98/250
# 16/16 [==============================] - 8s 487ms/step - loss: 3.0306e-04 - val_loss: 9.9966e-05
# Epoch 99/250
# 16/16 [==============================] - 8s 510ms/step - loss: 3.9001e-04 - val_loss: 7.7394e-05
# Epoch 100/250
# 16/16 [==============================] - 8s 492ms/step - loss: 5.0957e-04 - val_loss: 1.2961e-04
# Epoch 101/250
# 16/16 [==============================] - 8s 508ms/step - loss: 7.0885e-04 - val_loss: 1.6311e-04
# Epoch 102/250
# 16/16 [==============================] - 8s 488ms/step - loss: 3.0565e-04 - val_loss: 1.2410e-04
# Epoch 103/250
# 16/16 [==============================] - 8s 507ms/step - loss: 5.0863e-04 - val_loss: 9.9167e-05
# Epoch 104/250
# 16/16 [==============================] - 8s 512ms/step - loss: 3.8780e-04 - val_loss: 8.6394e-05
# Epoch 105/250
# 16/16 [==============================] - 8s 514ms/step - loss: 7.0435e-04 - val_loss: 1.2124e-04
# Epoch 106/250
# 16/16 [==============================] - 8s 511ms/step - loss: 5.7728e-04 - val_loss: 1.1166e-04
# Epoch 107/250
# 16/16 [==============================] - 9s 538ms/step - loss: 5.6125e-04 - val_loss: 8.2052e-05
# Epoch 108/250
# 16/16 [==============================] - 8s 498ms/step - loss: 2.4510e-04 - val_loss: 9.2087e-05
# Epoch 109/250
# 16/16 [==============================] - 9s 541ms/step - loss: 2.0923e-04 - val_loss: 8.0121e-05
# Epoch 110/250
# 16/16 [==============================] - 8s 499ms/step - loss: 2.8180e-04 - val_loss: 6.4312e-05
# Epoch 111/250
# 16/16 [==============================] - 8s 524ms/step - loss: 4.6716e-04 - val_loss: 6.7776e-05
# Epoch 112/250
# 16/16 [==============================] - 8s 495ms/step - loss: 3.2295e-04 - val_loss: 7.5666e-05
# Epoch 113/250
# 16/16 [==============================] - 8s 515ms/step - loss: 6.2316e-04 - val_loss: 5.2971e-05
# Epoch 114/250
# 16/16 [==============================] - 9s 548ms/step - loss: 5.2139e-04 - val_loss: 6.5908e-05
# Epoch 115/250
# 16/16 [==============================] - 10s 602ms/step - loss: 7.2442e-04 - val_loss: 6.8741e-05
# Epoch 116/250
# 16/16 [==============================] - 8s 497ms/step - loss: 3.0026e-04 - val_loss: 8.7020e-05
# Epoch 117/250
# 16/16 [==============================] - 8s 499ms/step - loss: 3.8983e-04 - val_loss: 7.7548e-05
# Epoch 118/250
# 16/16 [==============================] - 8s 497ms/step - loss: 4.6907e-04 - val_loss: 7.3420e-05
# Epoch 119/250
# 16/16 [==============================] - 8s 501ms/step - loss: 4.1119e-04 - val_loss: 7.2815e-05
# Epoch 120/250
# 16/16 [==============================] - 8s 495ms/step - loss: 3.8407e-04 - val_loss: 6.7904e-05
# Epoch 121/250
# 16/16 [==============================] - 8s 499ms/step - loss: 2.9037e-04 - val_loss: 5.4204e-05
# Epoch 122/250
# 16/16 [==============================] - 8s 492ms/step - loss: 2.6730e-04 - val_loss: 6.9639e-05
# Epoch 123/250
# 16/16 [==============================] - 8s 497ms/step - loss: 2.8942e-04 - val_loss: 6.8612e-05
# Epoch 124/250
# 16/16 [==============================] - 8s 487ms/step - loss: 2.8454e-04 - val_loss: 4.9717e-05
# Epoch 125/250
# 16/16 [==============================] - 8s 498ms/step - loss: 3.9979e-04 - val_loss: 5.5517e-05
# Epoch 126/250
# 16/16 [==============================] - 8s 490ms/step - loss: 4.2200e-04 - val_loss: 8.8615e-05
# Epoch 127/250
# 16/16 [==============================] - 8s 504ms/step - loss: 3.3510e-04 - val_loss: 1.0241e-04
# Epoch 128/250
# 16/16 [==============================] - 8s 492ms/step - loss: 2.8546e-04 - val_loss: 8.3936e-05
# Epoch 129/250
# 16/16 [==============================] - 8s 504ms/step - loss: 2.0413e-04 - val_loss: 8.9455e-05
# Epoch 130/250
# 16/16 [==============================] - 8s 495ms/step - loss: 3.2551e-04 - val_loss: 9.4119e-05
# Epoch 131/250
# 16/16 [==============================] - 8s 504ms/step - loss: 2.3400e-04 - val_loss: 5.5159e-05
# Epoch 132/250
# 16/16 [==============================] - 8s 495ms/step - loss: 2.9894e-04 - val_loss: 5.3632e-05
# Epoch 133/250
# 16/16 [==============================] - 8s 503ms/step - loss: 1.8384e-04 - val_loss: 6.7452e-05
# Epoch 134/250
# 16/16 [==============================] - 8s 493ms/step - loss: 2.8262e-04 - val_loss: 5.6547e-05
# Epoch 135/250
# 16/16 [==============================] - 8s 508ms/step - loss: 2.3375e-04 - val_loss: 6.0077e-05
# Epoch 136/250
# 16/16 [==============================] - 8s 495ms/step - loss: 3.8176e-04 - val_loss: 8.3102e-05
# Epoch 137/250
# 16/16 [==============================] - 8s 504ms/step - loss: 3.6430e-04 - val_loss: 5.6866e-05
# Epoch 138/250
# 16/16 [==============================] - 8s 532ms/step - loss: 3.7991e-04 - val_loss: 5.2705e-05
# Epoch 139/250
# 16/16 [==============================] - 8s 517ms/step - loss: 1.5607e-04 - val_loss: 6.5226e-05
# Epoch 140/250
# 16/16 [==============================] - 8s 516ms/step - loss: 3.6309e-04 - val_loss: 5.9072e-05
# Epoch 141/250
# 16/16 [==============================] - 8s 497ms/step - loss: 2.1927e-04 - val_loss: 5.6704e-05
# Epoch 142/250
# 16/16 [==============================] - 8s 499ms/step - loss: 2.7271e-04 - val_loss: 5.6666e-05
# Epoch 143/250
# 16/16 [==============================] - 8s 499ms/step - loss: 3.3294e-04 - val_loss: 6.4466e-05
# Epoch 144/250
# 16/16 [==============================] - 8s 503ms/step - loss: 3.3873e-04 - val_loss: 5.7051e-05
# Epoch 145/250
# 16/16 [==============================] - 8s 493ms/step - loss: 3.0574e-04 - val_loss: 6.0686e-05
# Epoch 146/250
# 16/16 [==============================] - 8s 497ms/step - loss: 1.7666e-04 - val_loss: 5.3604e-05
# Epoch 147/250
# 16/16 [==============================] - 8s 505ms/step - loss: 1.5244e-04 - val_loss: 4.9068e-05
# Epoch 148/250
# 16/16 [==============================] - 8s 497ms/step - loss: 1.3552e-04 - val_loss: 5.5955e-05
# Epoch 149/250
# 16/16 [==============================] - 8s 504ms/step - loss: 1.4018e-04 - val_loss: 6.0808e-05
# Epoch 150/250
# 16/16 [==============================] - 8s 493ms/step - loss: 1.3799e-04 - val_loss: 4.6064e-05
# Epoch 151/250
# 16/16 [==============================] - 8s 505ms/step - loss: 2.2660e-04 - val_loss: 5.4759e-05
# Epoch 152/250
# 16/16 [==============================] - 8s 500ms/step - loss: 4.3662e-04 - val_loss: 5.1499e-05
# Epoch 153/250
# 16/16 [==============================] - 8s 504ms/step - loss: 2.5119e-04 - val_loss: 4.5975e-05
# Epoch 154/250
# 16/16 [==============================] - 8s 504ms/step - loss: 2.6842e-04 - val_loss: 5.3054e-05
# Epoch 155/250
# 16/16 [==============================] - 8s 508ms/step - loss: 1.8829e-04 - val_loss: 6.5312e-05
# Epoch 156/250
# 16/16 [==============================] - 9s 553ms/step - loss: 2.6780e-04 - val_loss: 5.6296e-05
# Epoch 157/250
# 16/16 [==============================] - 9s 552ms/step - loss: 1.9355e-04 - val_loss: 5.1171e-05
# Epoch 158/250
# 16/16 [==============================] - 9s 597ms/step - loss: 1.5254e-04 - val_loss: 5.1419e-05
# Epoch 159/250
# 16/16 [==============================] - 10s 594ms/step - loss: 2.1433e-04 - val_loss: 5.3188e-05
# Epoch 160/250
# 16/16 [==============================] - 9s 545ms/step - loss: 1.1685e-04 - val_loss: 5.3296e-05
# Epoch 161/250
# 16/16 [==============================] - 8s 521ms/step - loss: 2.7731e-04 - val_loss: 5.6118e-05
# Epoch 162/250
# 16/16 [==============================] - 9s 579ms/step - loss: 3.6391e-04 - val_loss: 4.4246e-05
# Epoch 163/250
# 16/16 [==============================] - 9s 561ms/step - loss: 2.1144e-04 - val_loss: 4.7701e-05
# Epoch 164/250
# 16/16 [==============================] - 8s 522ms/step - loss: 2.1479e-04 - val_loss: 5.8567e-05
# Epoch 165/250
# 16/16 [==============================] - 8s 527ms/step - loss: 2.4365e-04 - val_loss: 6.6773e-05
# Epoch 166/250
# 16/16 [==============================] - 8s 527ms/step - loss: 1.9506e-04 - val_loss: 5.0509e-05
# Epoch 167/250
# 16/16 [==============================] - 9s 545ms/step - loss: 1.3756e-04 - val_loss: 4.6863e-05
# Epoch 168/250
# 16/16 [==============================] - 9s 592ms/step - loss: 2.1418e-04 - val_loss: 4.9110e-05
# Epoch 169/250
# 16/16 [==============================] - 10s 608ms/step - loss: 2.1214e-04 - val_loss: 5.8842e-05
# Epoch 170/250
# 16/16 [==============================] - 9s 546ms/step - loss: 1.4055e-04 - val_loss: 5.7687e-05
# Epoch 171/250
# 16/16 [==============================] - 9s 543ms/step - loss: 2.1539e-04 - val_loss: 6.1337e-05
# Epoch 172/250
# 16/16 [==============================] - 9s 575ms/step - loss: 1.2536e-04 - val_loss: 5.2106e-05
# Epoch 173/250
# 16/16 [==============================] - 9s 577ms/step - loss: 1.1517e-04 - val_loss: 4.1245e-05
# Epoch 174/250
# 16/16 [==============================] - 9s 549ms/step - loss: 2.3776e-04 - val_loss: 4.0225e-05
# Epoch 175/250
# 16/16 [==============================] - 9s 551ms/step - loss: 7.8117e-05 - val_loss: 5.4378e-05
# Epoch 176/250
# 16/16 [==============================] - 8s 531ms/step - loss: 1.8568e-04 - val_loss: 3.8897e-05
# Epoch 177/250
# 16/16 [==============================] - 8s 512ms/step - loss: 1.7084e-04 - val_loss: 4.0808e-05
# Epoch 178/250
# 16/16 [==============================] - 8s 533ms/step - loss: 1.6067e-04 - val_loss: 3.7690e-05
# Epoch 179/250
# 16/16 [==============================] - 8s 514ms/step - loss: 1.4508e-04 - val_loss: 5.6586e-05
# Epoch 180/250
# 16/16 [==============================] - 9s 545ms/step - loss: 2.0846e-04 - val_loss: 6.0677e-05
# Epoch 181/250
# 16/16 [==============================] - 8s 518ms/step - loss: 2.8986e-04 - val_loss: 5.4118e-05
# Epoch 182/250
# 16/16 [==============================] - 8s 528ms/step - loss: 1.5417e-04 - val_loss: 4.7380e-05
# Epoch 183/250
# 16/16 [==============================] - 8s 486ms/step - loss: 1.2375e-04 - val_loss: 4.7276e-05
# Epoch 184/250
# 16/16 [==============================] - 9s 542ms/step - loss: 1.2448e-04 - val_loss: 4.4816e-05
# Epoch 185/250
# 16/16 [==============================] - 8s 532ms/step - loss: 1.6600e-04 - val_loss: 4.9839e-05
# Epoch 186/250
# 16/16 [==============================] - 8s 531ms/step - loss: 2.5791e-04 - val_loss: 5.6375e-05
# Epoch 187/250
# 16/16 [==============================] - 8s 509ms/step - loss: 2.3486e-04 - val_loss: 5.8538e-05
# Epoch 188/250
# 16/16 [==============================] - 8s 514ms/step - loss: 2.5640e-04 - val_loss: 5.3082e-05
# Epoch 189/250
# 16/16 [==============================] - 8s 493ms/step - loss: 1.4666e-04 - val_loss: 4.8329e-05
# Epoch 190/250
# 16/16 [==============================] - 8s 503ms/step - loss: 2.0456e-04 - val_loss: 4.6287e-05
# Epoch 191/250
# 16/16 [==============================] - 8s 493ms/step - loss: 1.0916e-04 - val_loss: 3.8863e-05
# Epoch 192/250
# 16/16 [==============================] - 8s 512ms/step - loss: 7.2286e-05 - val_loss: 4.7380e-05
# Epoch 193/250
# 16/16 [==============================] - 8s 504ms/step - loss: 1.2481e-04 - val_loss: 4.5313e-05
# Epoch 194/250
# 16/16 [==============================] - 8s 515ms/step - loss: 9.3841e-05 - val_loss: 4.1407e-05
# Epoch 195/250
# 16/16 [==============================] - 8s 521ms/step - loss: 8.4588e-05 - val_loss: 4.4419e-05
# Epoch 196/250
# 16/16 [==============================] - 8s 499ms/step - loss: 1.3868e-04 - val_loss: 3.4342e-05
# Epoch 197/250
# 16/16 [==============================] - 8s 495ms/step - loss: 2.0488e-04 - val_loss: 4.0903e-05
# Epoch 198/250
# 16/16 [==============================] - 8s 533ms/step - loss: 1.6050e-04 - val_loss: 5.3487e-05
# Epoch 199/250
# 16/16 [==============================] - 9s 529ms/step - loss: 2.1090e-04 - val_loss: 5.5477e-05
# Epoch 200/250
# 16/16 [==============================] - 8s 531ms/step - loss: 1.6269e-04 - val_loss: 4.5679e-05
# Epoch 201/250
# 16/16 [==============================] - 10s 650ms/step - loss: 1.3477e-04 - val_loss: 4.2684e-05
# Epoch 202/250
# 16/16 [==============================] - 10s 603ms/step - loss: 4.6540e-04 - val_loss: 8.4292e-05
# Epoch 203/250
# 16/16 [==============================] - 9s 546ms/step - loss: 1.4940e-04 - val_loss: 7.1209e-05
# Epoch 204/250
# 16/16 [==============================] - 9s 563ms/step - loss: 2.1677e-04 - val_loss: 7.2893e-05
# Epoch 205/250
# 16/16 [==============================] - 10s 603ms/step - loss: 1.6431e-04 - val_loss: 6.6954e-05
# Epoch 206/250
# 16/16 [==============================] - 9s 553ms/step - loss: 7.4434e-05 - val_loss: 6.1668e-05
# Epoch 207/250
# 16/16 [==============================] - 9s 576ms/step - loss: 1.7293e-04 - val_loss: 8.2611e-05
# Epoch 208/250
# 16/16 [==============================] - 9s 582ms/step - loss: 1.4030e-04 - val_loss: 6.6169e-05
# Epoch 209/250
# 16/16 [==============================] - 8s 523ms/step - loss: 2.9343e-04 - val_loss: 4.9786e-05
# Epoch 210/250
# 16/16 [==============================] - 8s 526ms/step - loss: 1.4060e-04 - val_loss: 7.6536e-05
# Epoch 211/250
# 16/16 [==============================] - 8s 511ms/step - loss: 1.8506e-04 - val_loss: 4.6743e-05
# Epoch 212/250
# 16/16 [==============================] - 8s 510ms/step - loss: 2.3947e-04 - val_loss: 4.3309e-05
# Epoch 213/250
# 16/16 [==============================] - 8s 505ms/step - loss: 2.4877e-04 - val_loss: 6.7097e-05
# Epoch 214/250
# 16/16 [==============================] - 8s 533ms/step - loss: 1.1364e-04 - val_loss: 4.6959e-05
# Epoch 215/250
# 16/16 [==============================] - 8s 501ms/step - loss: 1.7295e-04 - val_loss: 4.2139e-05
# Epoch 216/250
# 16/16 [==============================] - 8s 506ms/step - loss: 1.6434e-04 - val_loss: 4.8011e-05
# Epoch 217/250
# 16/16 [==============================] - 8s 504ms/step - loss: 9.4041e-05 - val_loss: 4.7781e-05
# Epoch 218/250
# 16/16 [==============================] - 8s 515ms/step - loss: 1.4835e-04 - val_loss: 4.6876e-05
# Epoch 219/250
# 16/16 [==============================] - 8s 497ms/step - loss: 7.1306e-05 - val_loss: 4.2323e-05
# Epoch 220/250
# 16/16 [==============================] - 8s 517ms/step - loss: 1.1566e-04 - val_loss: 3.9525e-05
# Epoch 221/250
# 16/16 [==============================] - 8s 500ms/step - loss: 7.3195e-05 - val_loss: 3.9423e-05
# Epoch 222/250
# 16/16 [==============================] - 8s 507ms/step - loss: 1.2840e-04 - val_loss: 4.3011e-05
# Epoch 223/250
# 16/16 [==============================] - 8s 496ms/step - loss: 9.5822e-05 - val_loss: 4.2711e-05
# Epoch 224/250
# 16/16 [==============================] - 8s 494ms/step - loss: 2.0134e-04 - val_loss: 5.3993e-05
# Epoch 225/250
# 16/16 [==============================] - 8s 480ms/step - loss: 1.8325e-04 - val_loss: 3.9977e-05
# Epoch 226/250
# 16/16 [==============================] - 8s 509ms/step - loss: 7.8370e-05 - val_loss: 4.9564e-05
# Epoch 227/250
# 16/16 [==============================] - 8s 484ms/step - loss: 1.1416e-04 - val_loss: 4.6830e-05
# Epoch 228/250
# 16/16 [==============================] - 8s 497ms/step - loss: 7.3127e-05 - val_loss: 4.4950e-05
# Epoch 229/250
# 16/16 [==============================] - 8s 484ms/step - loss: 7.6607e-05 - val_loss: 4.8336e-05
# Epoch 230/250
# 16/16 [==============================] - 8s 505ms/step - loss: 1.9520e-04 - val_loss: 4.3918e-05
# Epoch 231/250
# 16/16 [==============================] - 8s 490ms/step - loss: 1.6691e-04 - val_loss: 4.6579e-05
# Epoch 232/250
# 16/16 [==============================] - 8s 504ms/step - loss: 9.9235e-05 - val_loss: 5.0985e-05
# Epoch 233/250
# 16/16 [==============================] - 8s 483ms/step - loss: 1.7800e-04 - val_loss: 4.6017e-05
# Epoch 234/250
# 16/16 [==============================] - 8s 497ms/step - loss: 1.0325e-04 - val_loss: 4.9295e-05
# Epoch 235/250
# 16/16 [==============================] - 8s 484ms/step - loss: 6.9012e-05 - val_loss: 4.0765e-05
# Epoch 236/250
# 16/16 [==============================] - 8s 508ms/step - loss: 1.1875e-04 - val_loss: 4.3979e-05
# Epoch 237/250
# 16/16 [==============================] - 8s 488ms/step - loss: 1.7257e-04 - val_loss: 4.8326e-05
# Epoch 238/250
# 16/16 [==============================] - 8s 504ms/step - loss: 1.4068e-04 - val_loss: 5.6002e-05
# Epoch 239/250
# 16/16 [==============================] - 8s 495ms/step - loss: 1.8973e-04 - val_loss: 5.0328e-05
# Epoch 240/250
# 16/16 [==============================] - 8s 515ms/step - loss: 1.0159e-04 - val_loss: 4.7840e-05
# Epoch 241/250
# 16/16 [==============================] - 8s 489ms/step - loss: 1.1869e-04 - val_loss: 4.6619e-05
# Epoch 242/250
# 16/16 [==============================] - 8s 521ms/step - loss: 1.2820e-04 - val_loss: 5.8563e-05
# Epoch 243/250
# 16/16 [==============================] - 8s 499ms/step - loss: 9.1847e-05 - val_loss: 5.3314e-05
# Epoch 244/250
# 16/16 [==============================] - 8s 528ms/step - loss: 1.5741e-04 - val_loss: 4.3219e-05
# Epoch 245/250
# 16/16 [==============================] - 8s 521ms/step - loss: 6.1536e-05 - val_loss: 3.7414e-05
# Epoch 246/250
# 16/16 [==============================] - 8s 529ms/step - loss: 1.1322e-04 - val_loss: 3.7843e-05
# Epoch 247/250
# 16/16 [==============================] - 8s 519ms/step - loss: 9.9738e-05 - val_loss: 4.8615e-05
# Epoch 248/250
# 16/16 [==============================] - 8s 522ms/step - loss: 1.1523e-04 - val_loss: 4.9773e-05
# Epoch 249/250
# 16/16 [==============================] - 8s 510ms/step - loss: 1.5028e-04 - val_loss: 5.4439e-05
# Epoch 250/250
# 16/16 [==============================] - 8s 519ms/step - loss: 1.7689e-04 - val_loss: 5.5166e-05
# Training time: 0:35:20.494390

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 6.153585127322003e-05
# Validation loss 3.434249811107293e-05

# %%
# Plot the prediction of the model for the training and validation sets
pred_train = model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = model.predict([testx, testx_2, testx_4, testx_8])
# Out:
# 4/4 [==============================] - 10s 219ms/step
# 2/2 [==============================] - 0s 62ms/step

# %%
plt.figure(figsize = (8,8))
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(test_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.1,1.1])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()
plt.savefig('TCN_LR0003_E250.png', dpi=350)
plt.show()

# %%
# Calculate the cumulative deviation and rms deviation for the validation set
test_dev = abs(np.squeeze(pred_test)-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
rms_dev = sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
# Out:
# Mean absolute deviation: 0.009180350063641866
# RMS deviation: 0.015013089676905705

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, explained_variance_score
#r2
score = r2_score(test_y, pred_test)
print("The accuracy of our model is {}%".format(round(score, 4) *100))
#
mae_score = mean_absolute_error(test_y, pred_test)
print("The Mean Absolute Error of our Model is {}".format(round(mae_score, 6)))
#
mse_score = mean_squared_error(test_y, pred_test)
print("The Mean Squared Error of our Model is {}".format(round(mae_score, 6)))
#
rmse_score = np.sqrt(mean_squared_error(test_y, pred_test))
print("The Root Mean Squared Error of our Model is {}".format(round(rmse_score, 6)))
#
ev_score = explained_variance_score(test_y, pred_test)
print("The EV Score of our Model is {}".format(round(ev_score, 6)))
# Out:
# The accuracy of our model is 2.79%
# The Mean Absolute Error of our Model is 0.00918
# The Mean Squared Error of our Model is 0.00918
# The Root Mean Squared Error of our Model is 0.015013
# The EV Score of our Model is 0.245595
