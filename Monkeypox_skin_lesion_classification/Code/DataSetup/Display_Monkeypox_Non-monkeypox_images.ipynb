# %%
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from skimage import transform, exposure
from skimage.transform import rotate, AffineTransform
from skimage.util import random_noise
from skimage.filters import gaussian, unsharp_mask
from scipy import ndimage
from skimage.io import imread, imsave
from pathlib import Path
from keras import layers, models
from skimage.color import rgb2hed, hed2rgb

# %%
# 
monkeypox_img_dir = 'D:Development/Data_Science_Datasets/Monkeypox_skinlesion/displayImages/Monkeypox/'
nonmonkeypox_img_dir = 'D:Development/Data_Science_Datasets/Monkeypox_skinlesion/displayImages/Non-Monkeypox/'

monkeypox_images = Path(monkeypox_img_dir).glob('*.jpg')
nonmonkeypox_images = Path(nonmonkeypox_img_dir).glob('*.jpg')

# setting values to rows and column variables
rows = 2
columns = 3

# %%
monkeypox_images = Path(monkeypox_img_dir).glob('*.jpg')
images = []
for monkeypox_image in monkeypox_images:    
    images.append(imread(monkeypox_image))

# %%
# create figure
fig = plt.figure()
fig.suptitle("Monkeypox", fontsize=14)

#First Image
fig.add_subplot(rows, columns, 1)            
plt.imshow(images[0])
plt.axis('off')
    
#Second Image
fig.add_subplot(rows, columns, 2)            
plt.imshow(images[1])
plt.axis('off')
    
#Third Image    
fig.add_subplot(rows, columns, 3)            
plt.imshow(images[2])
plt.axis('off')
    
#Forth Image
fig.add_subplot(rows, columns, 4)            
plt.imshow(images[3])
plt.axis('off')
    
#Fifth Image
fig.add_subplot(rows, columns, 5)            
plt.imshow(images[4])
plt.axis('off')
    
#Sixth Image
fig.add_subplot(rows, columns, 6)            
plt.imshow(images[5])
plt.axis('off')
# Out:
# (-0.5, 223.5, 223.5, -0.5)

# %%
nonmonkeypox_images = Path(nonmonkeypox_img_dir).glob('*.jpg')
nmimages = []
for nonmonkeypox_image in nonmonkeypox_images:    
    nmimages.append(imread(nonmonkeypox_image))

# %%
# create figure
fig = plt.figure()
fig.suptitle("Non-Monkeypox", fontsize=14)

#First Image
fig.add_subplot(rows, columns, 1)            
plt.imshow(nmimages[0])
plt.axis('off')
    
#Second Image
fig.add_subplot(rows, columns, 2)            
plt.imshow(nmimages[1])
plt.axis('off')
    
#Third Image    
fig.add_subplot(rows, columns, 3)            
plt.imshow(nmimages[2])
plt.axis('off')
    
#Forth Image
fig.add_subplot(rows, columns, 4)            
plt.imshow(nmimages[3])
plt.axis('off')
    
#Fifth Image
fig.add_subplot(rows, columns, 5)            
plt.imshow(nmimages[4])
plt.axis('off')
    
#Sixth Image
fig.add_subplot(rows, columns, 6)            
plt.imshow(nmimages[5])
plt.axis('off')
# Out:
# (-0.5, 223.5, 223.5, -0.5)
